# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.0)

# %% [markdown]
# Scrape Nominations

# %%
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import time

base_url = "https://en.wikipedia.org"

awards = {}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
                   (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36"
}

def get_suffix(number):
    if 10 <= number % 100 <= 20:
        return "th"
    return {1: "st", 2: "nd", 3: "rd"}.get(number % 10, "th")

for i in range(10, 98):
    suffix = get_suffix(i)
    url = f"https://en.wikipedia.org/wiki/{i}{suffix}_Academy_Awards"
    try:
        response = requests.get(url, headers=headers)
        print(f"Fetching: {url} - Status: {response.status_code}")
        while(response.status_code!=200):
          time.sleep(5)
          response = requests.get(url)
          print(f"Fetching: {url} - Status: {response.status_code}")

        soup = BeautifulSoup(response.content, "html.parser")
        table = soup.find("table", class_="wikitable")
        if not table:
            print("No table found on page.")
            continue

        tds = table.find_all("td")
        awards[i] = {}
        categories = table.find_all("th")
        for index, td in enumerate(tds):
            if(categories == []):
                category = td.find('b')
            else:
              category = categories[index]
            print(category.text)
            print("-" * 40)
            awards[i][category.text] = {
                "nominations": [],
                "winners": []
            }
            nominies = td.find("ul")
            if not nominies:
                continue
            nominiesTxt = nominies.get_text()
            for line in nominiesTxt.strip().split('\n'):
                if '‡' in line:
                    line = line.replace('‡', '').strip()
                    awards[i][category.text]["winners"].append(line)
                else:
                    line = line.strip()
                    awards[i][category.text]["nominations"].append(line)
    except Exception as e:
        print(f"Error processing {url}: {e}")
# Your existing awards data processing
awards_data = []
for year, categories in awards.items():
    for category, details in categories.items():
        winners = details["winners"]  # List of winners
        nominations = details["nominations"] + winners  # Treat winners as nominations as well

        for nomination in nominations:
            won = 1 if nomination in winners else 0  # Check if the nomination is in the winners list
            awards_data.append([year, category, nomination, won])

# Create the DataFrame
awards_df = pd.DataFrame(awards_data, columns=["iteration", "Category", "Nomination", "Won"])

# Display the DataFrame
print(awards_df)
# Out:
# Fetching: https://en.wikipedia.org/wiki/10th_Academy_Awards - Status: 200
# Outstanding Production
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Story)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Color)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Scoring)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Dance Direction
# ----------------------------------------
# Best Assistant Director
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/11th_Academy_Awards - Status: 200
# Outstanding Production
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Story)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Scoring)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/12th_Academy_Awards - Status: 200
# Outstanding Production
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Story)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Scoring)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction
# ----------------------------------------
# Best Cinematography (Black-and-White)
# ----------------------------------------
# Best Cinematography (Color)
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Special Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/13th_Academy_Awards - Status: 200
# Outstanding Production
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Writing (Original Story)
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Scoring)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction (Black-and-White)
# ----------------------------------------
# Best Art Direction (Color)
# ----------------------------------------
# Best Cinematography (Black-and-White)
# ----------------------------------------
# Best Cinematography (Color)
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Special Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/14th_Academy_Awards - Status: 200
# Outstanding Motion Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Writing (Original Story)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Music Score of a Dramatic Picture)
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction (Black-and-White)
# ----------------------------------------
# Best Art Direction (Color)
# ----------------------------------------
# Best Cinematography (Black-and-White)
# ----------------------------------------
# Best Cinematography (Color)
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Special Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/15th_Academy_Awards - Status: 200
# Outstanding Motion Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Writing (Original Motion Picture Story)
# ----------------------------------------
# Best Documentary
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction (Black-and-White)
# ----------------------------------------
# Best Art Direction (Color)
# ----------------------------------------
# Best Cinematography (Black-and-White)
# ----------------------------------------
# Best Cinematography (Color)
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Special Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/16th_Academy_Awards - Status: 200
# Outstanding Motion Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Writing (Original Motion Picture Story)
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction (Black-and-White)
# ----------------------------------------
# Best Art Direction (Color)
# ----------------------------------------
# Best Cinematography (Black-and-White)
# ----------------------------------------
# Best Cinematography (Color)
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Special Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/17th_Academy_Awards - Status: 200
# Best Motion Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor
# ----------------------------------------
# Best Actress
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Screenplay)
# ----------------------------------------
# Best Writing (Original Motion Picture Story)
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Subject (One-Reel)
# ----------------------------------------
# Best Short Subject (Two-Reel)
# ----------------------------------------
# Best Short Subject (Cartoon)
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
# ----------------------------------------
# Best Music (Song)
# ----------------------------------------
# Best Sound Recording
# ----------------------------------------
# Best Art Direction (Black-and-White)
# ----------------------------------------
# Best Art Direction (Color)
# ----------------------------------------
# Best Cinematography (Black-and-White)
# ----------------------------------------
# Best Cinematography (Color)
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Special Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/18th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Original Screenplay)
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Original Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/19th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Original Screenplay)
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Original Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/20th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Original Screenplay)
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/21st_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/22nd_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Story and Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/23rd_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Story and Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/24th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay)
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/25th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Story and Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/26th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Story and Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/27th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Story and Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/28th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Screenplay)
#
# ----------------------------------------
# Best Writing (Story and Screenplay)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/29th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best  Writing (Screenplay -- Original)
#
# ----------------------------------------
# Best Writing (Screenplay -- Adapted)
#
# ----------------------------------------
# Best Writing (Motion Picture Story)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (One-Reel)
#
# ----------------------------------------
# Best Short Subject (Two-Reel)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/30th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Short Subject (Live Action)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Scoring)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Recording
#
# ----------------------------------------
# Best Costume Design
#
# ----------------------------------------
# Best Art Direction
#
# ----------------------------------------
# Best Cinematography
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/31st_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (Live Action)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound
#
# ----------------------------------------
# Best Art Direction
#
# ----------------------------------------
# Best Costume Design
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/32nd_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (Live Action)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/33rd_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (Live Action)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/34th_Academy_Awards - Status: 200
# Best Motion Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (Live Action)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score of a Dramatic or Comedy Picture)
#
# ----------------------------------------
# Best Music (Scoring of a Musical Picture)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/35th_Academy_Awards - Status: 200
# Best Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (Live Action)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score -- Substantially Original)
#
# ----------------------------------------
# Best Music (Scoring of Music -- Adaptation or Treatment)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/36th_Academy_Awards - Status: 200
# Best Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# Best Foreign Language Film
#
# ----------------------------------------
# Best Documentary (Feature)
#
# ----------------------------------------
# Best Documentary (Short Subject)
#
# ----------------------------------------
# Best Short Subject (Live Action)
#
# ----------------------------------------
# Best Short Subject (Cartoon)
#
# ----------------------------------------
# Best Music (Music Score -- Substantially Original)
#
# ----------------------------------------
# Best Music (Scoring of Music -- Adaptation or Treatment)
#
# ----------------------------------------
# Best Music (Song)
#
# ----------------------------------------
# Best Sound Effects
#
# ----------------------------------------
# Best Sound
#
# ----------------------------------------
# Best Art Direction (Black-and-White)
#
# ----------------------------------------
# Best Art Direction (Color)
#
# ----------------------------------------
# Best Cinematography (Black-and-White)
#
# ----------------------------------------
# Best Cinematography (Color)
#
# ----------------------------------------
# Best Costume Design (Black-and-White)
#
# ----------------------------------------
# Best Costume Design (Color)
#
# ----------------------------------------
# Best Film Editing
#
# ----------------------------------------
# Best Special Effects
#
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/37th_Academy_Awards - Status: 200
# Best Picture
#
# ----------------------------------------
# Best Directing
#
# ----------------------------------------
# Best Actor
#
# ----------------------------------------
# Best Actress
#
# ----------------------------------------
# Best Actor in a Supporting Role
#
# ----------------------------------------
# Best Actress in a Supporting Role
#
# ----------------------------------------
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
#
# ----------------------------------------
# Best Writing (Screenplay -- Based on Material from Another Medium)
#
# ----------------------------------------
# ...
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best Foreign Language Film
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound Editing
# ----------------------------------------
# Best Sound Mixing
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/89th_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best Foreign Language Film
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound Editing
# ----------------------------------------
# Best Sound Mixing
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/90th_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
#  Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best Foreign Language Film
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound Editing
# ----------------------------------------
# Best Sound Mixing
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/91st_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best Foreign Language Film
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound Editing
# ----------------------------------------
# Best Sound Mixing
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/92nd_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best International Feature Film
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound Editing
# ----------------------------------------
# Best Sound Mixing
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/93rd_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best International Feature Film
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/94th_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best International Feature Film
# ----------------------------------------
# Best Documentary (Feature)
# ----------------------------------------
# Best Documentary (Short Subject)
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/95th_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best International Feature Film
# ----------------------------------------
# Best Documentary Feature Film
# ----------------------------------------
# Best Documentary Short Film
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/96th_Academy_Awards - Status: 200
# Best Picture
# ----------------------------------------
# Best Directing
# ----------------------------------------
# Best Actor in a Leading Role
# ----------------------------------------
# Best Actress in a Leading Role
# ----------------------------------------
# Best Actor in a Supporting Role
# ----------------------------------------
# Best Actress in a Supporting Role
# ----------------------------------------
# Best Writing (Original Screenplay)
# ----------------------------------------
# Best Writing (Adapted Screenplay)[22]
# ----------------------------------------
# Best Animated Feature Film
# ----------------------------------------
# Best International Feature Film
# ----------------------------------------
# Best Documentary Feature Film
# ----------------------------------------
# Best Documentary Short Film
# ----------------------------------------
# Best Short Film (Live Action)
# ----------------------------------------
# Best Short Film (Animated)
# ----------------------------------------
# Best Music (Original Score)
# ----------------------------------------
# Best Music (Original Song)
# ----------------------------------------
# Best Sound
# ----------------------------------------
# Best Production Design
# ----------------------------------------
# Best Cinematography
# ----------------------------------------
# Best Makeup and Hairstyling
# ----------------------------------------
# Best Costume Design
# ----------------------------------------
# Best Film Editing
# ----------------------------------------
# Best Visual Effects
# ----------------------------------------
# Fetching: https://en.wikipedia.org/wiki/97th_Academy_Awards - Status: 200
# Date
#
# ----------------------------------------
# Event
#
# ----------------------------------------
#        iteration                Category  \
# 0             10  Outstanding Production
# 1             10  Outstanding Production
# 2             10  Outstanding Production
# 3             10  Outstanding Production
# 4             10  Outstanding Production
# ...          ...                     ...
# 10032         96     Best Visual Effects
# 10033         96     Best Visual Effects
# 10034         96     Best Visual Effects
# 10035         96     Best Visual Effects
# 10036         96     Best Visual Effects
#
#                                               Nomination  Won
# 0      The Awful Truth – Leo McCarey and Everett Risk...    0
# 1      Captains Courageous – Louis D. Lighton for Met...    0
# 2      Dead End – Samuel Goldwyn and Merritt Hulbert ...    0
# 3      The Good Earth – Irving Thalberg and Albert Le...    0
# 4      In Old Chicago – Darryl F. Zanuck and Kenneth ...    0
# ...                                                  ...  ...
# 10032  The Creator – Jay Cooper, Ian Comley, Andrew R...    0
# 10033  Guardians of the Galaxy Vol. 3 – Stéphane Cere...    0
# 10034  Mission: Impossible – Dead Reckoning Part One ...    0
# 10035  Napoleon – Charley Henley, Luc-Ewen Martin-Fen...    0
# 10036  Godzilla Minus One – Takashi Yamazaki, Kiyoko ...    1
#
# [10037 rows x 4 columns]

# %%
print(awards)
# Out:
# {10: {'Outstanding Production': {'nominations': ['The Awful Truth – Leo McCarey and Everett Riskin for Columbia', 'Captains Courageous – Louis D. Lighton for Metro-Goldwyn-Mayer', 'Dead End – Samuel Goldwyn and Merritt Hulbert for Samuel Goldwyn Prod. and United Artists', 'The Good Earth – Irving Thalberg and Albert Lewin for Metro-Goldwyn-Mayer', 'In Old Chicago – Darryl F. Zanuck and Kenneth Macgowan for 20th Century Fox', 'Lost Horizon – Frank Capra for Columbia', 'One Hundred Men and a Girl – Charles R. Rogers and Joe Pasternak for Universal', 'Stage Door – Pandro S. Berman for RKO Radio', 'A Star Is Born – David O. Selznick for Selznick International and United Artists'], 'winners': ['The Life of Emile Zola – Henry Blanke for Warner Bros.']}, 'Best Directing': {'nominations': ['Sidney Franklin\xa0– The Good Earth', 'William Dieterle\xa0– The Life of Emile Zola', 'Gregory La Cava\xa0– Stage Door', 'William Wellman\xa0– A Star Is Born'], 'winners': ['Leo McCarey\xa0– The Awful Truth']}, 'Best Actor': {'nominations': ['Charles Boyer\xa0– Conquest as Napoleon Bonaparte', 'Fredric March\xa0– A Star Is Born as Norman Maine', 'Robert Montgomery\xa0– Night Must Fall as Danny', 'Paul Muni\xa0– The Life of Emile Zola as Émile Zola'], 'winners': ['Spencer Tracy\xa0– Captains Courageous as Manuel Fidello']}, 'Best Actress': {'nominations': ['Irene Dunne\xa0– The Awful Truth as Lucy Warriner', 'Greta Garbo\xa0– Camille as Marguerite Gautier', 'Janet Gaynor\xa0– A Star Is Born as Esther Blodgett/Vicki Lester', 'Barbara Stanwyck\xa0– Stella Dallas as Stella Dallas'], 'winners': ['Luise Rainer\xa0– The Good Earth as O-Lan']}, 'Best Actor in a Supporting Role': {'nominations': ['Ralph Bellamy\xa0– The Awful Truth as Dan Leeson', 'Thomas Mitchell\xa0– The Hurricane as Dr. Kersaint', 'H. B. Warner\xa0– Lost Horizon as Chang', 'Roland Young\xa0– Topper as Cosmo Topper'], 'winners': ['Joseph Schildkraut\xa0– The Life of Emile Zola as Alfred Dreyfus']}, 'Best Actress in a Supporting Role': {'nominations': ['Andrea Leeds\xa0– Stage Door as Kay Hamilton', 'Anne Shirley\xa0– Stella Dallas as Laurel Dallas', 'Claire Trevor\xa0– Dead End as Francey', 'May Whitty\xa0– Night Must Fall as Mrs Bramson'], 'winners': ["Alice Brady\xa0– In Old Chicago as Molly O'Leary"]}, 'Best Writing (Original Story)': {'nominations': ['Black Legion\xa0– Robert Lord', 'In Old Chicago\xa0– Niven Busch', 'The Life of Emile Zola\xa0– Heinz Herald and Geza Herczeg', 'One Hundred Men and a Girl\xa0– Hanns Kräly'], 'winners': ['A Star Is Born\xa0– William A. Wellman and Robert Carson']}, 'Best Writing (Screenplay)': {'nominations': ['The Awful Truth\xa0– Viña Delmar, based on the play by Arthur Richman', 'Captains Courageous\xa0– John Lee Mahin, Marc Connelly, and Dale Van Every, based on the novel by Rudyard Kipling', 'Stage Door\xa0– Morris Ryskind and Anthony Veiller, based on the play by Edna Ferber and George S. Kaufman', 'A Star Is Born\xa0– Alan Campbell, Robert Carson, and Dorothy Parker, based on a story by William A. Wellman and Robert Carson'], 'winners': ['The Life of Emile Zola\xa0– Heinz Herald, Geza Herczeg, and Norman Reilly Raine, based on Zola and His Time by Matthew Josephson']}, 'Best Short Subject (One-Reel)': {'nominations': ['A Night at the Movies\xa0– MGM', 'Romance of Radium\xa0– Pete Smith and MGM'], 'winners': ['The Private Life of the Gannets\xa0– Skibo Productions and Educational']}, 'Best Short Subject (Two-Reel)': {'nominations': ['Deep South\xa0– RKO Radio', 'Should Wives Work?\xa0– RKO Radio'], 'winners': ['Torture Money\xa0– MGM']}, 'Best Short Subject (Color)': {'nominations': ['The Man Without a Country\xa0– Warner Bros.', 'Popular Science J-7-1\xa0– Paramount'], 'winners': ['Penny Wisdom\xa0– Pete Smith and MGM']}, 'Best Short Subject (Cartoon)': {'nominations': ['Educated Fish\xa0– Paramount', 'The Little Match Girl\xa0– Charles Mintz and Columbia'], 'winners': ['The Old Mill\xa0– Walt Disney Productions and RKO Radio']}, 'Best Music (Sco ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **Scrape Actors and Movies**

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re
from datetime import datetime

#
base_url = "https://en.wikipedia.org"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
                   (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36"
}


visited_actors = set()
visited_movies = set()

actors = []
movies = []


def generate_date(text):
      # Try to match a date directly in YYYY-MM-DD format
    date_match = re.search(r'(\d{4}-\d{2}-\d{2})', str(text))
    if date_match:
        return date_match.group(1)
    # Try to match month, day, and year
    date_match = re.search(r'([A-Za-z]+)\s*(\d{1,2})\s*,\s*(\d{4})', str(text))
    if date_match:
        month_str, day, year = date_match.groups()
        # Convert month name to number
        month_num = datetime.strptime(month_str, "%B").month
        # Create a date string in YYYY-MM-DD format
        return f"{year}-{month_num:02d}-{int(day):02d}"
    return text




def get_suffix(number):
    if 10 <= number % 100 <= 20:
        return "th"
    return {1: "st", 2: "nd", 3: "rd"}.get(number % 10, "th")


def fetch_page(url):
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
           print(f"Fetched: {url}")
           return BeautifulSoup(response.content, "html.parser")
        print(f"Failed to fetch {url} - Status: {response.status_code}")
    except Exception as e:
        print(f"Error fetching {url}: {e}")
    return None


def extract_actor_info(actor_name, actor_link):
    if actor_link in visited_actors:
        print (f"Skipping {actor_name}- {actor_link} (already visited) ")
        return None
    visited_actors.add(actor_link)
    actor_soup = fetch_page(actor_link)
    if not actor_soup:
        return None
    bio = actor_soup.find("table", class_="infobox")
    if not bio:
      print(f"infobox not found for {actor_name} - {actor_link}")
      return None
    actor_info = {"name": actor_name, "DOB": "N/A", "Birth Country": "N/A", "DOD": "N/A"}
    for field in ["Born", "Died"]:
        row = bio.find("th", string=field)
        if row:
            data = row.find_next_sibling("td")
            if data:
                text = data.get_text(separator=" ", strip=True)
                date = generate_date(text)
                parts = text.split(", ")
                if field == "Born":
                    if re.search(r'\d{4}', text):  # Check if a year is present (indicating it's a date)
                        actor_info["DOB"] = date
                    if len(parts) > 1:  # If both date and country are present
                        actor_info["Birth Country"] = parts[-1]
                    elif len(parts) == 1:  # If only country is present
                        actor_info["Birth Country"] = parts[0]
                elif field == "Died":
                    actor_info["DOD"] = date
    actors.append(actor_info)
    return actor_info


def extract_movie_info(movie_name, movie_link):
    if movie_link in visited_movies:
        print (f"Skipping {movie_name}- {movie_link} (already visited) ")
        return None
    visited_movies.add(movie_link)
    movie_soup = fetch_page(movie_link)
    if not movie_soup:
        return None
    info = movie_soup.find("table", class_="infobox")
    if not info:
      print(f"infobox not found for {movie_name} - {movie_link}")
      return None
    movie_data = {"Name": movie_name, "Release date": "N/A", "Distributed by": "N/A", "Language": "N/A", "Running time": "N/A"}
    fields = ["Distributed by", "Release date", "Release dates", "Language", "Running time"]
    for field in fields:
        row = info.find("th", string=field)
        if row:
            data = row.find_next_sibling("td")
            if data:
                # Remove unnecessary tags and get clean text
                for sup in data.find_all("sup"):
                    sup.decompose()
                list_item = data.find("li")
                text = list_item.get_text(separator=" ", strip=True) if list_item else data.get_text(separator=" ", strip=True)
                if field == "Release dates" or field == "Release date" :
                    date_container = data.find("div", class_="film-date")
                    if date_container:
                        first_date = date_container.find("li")
                        if first_date:
                            text = first_date.get_text(separator=" ", strip=True)
                            date_match = re.search(r'(\d{4}-\d{2}-\d{2})', str(first_date))
                            numerical_date = date_match.group(1) if date_match else generate_date(text)
                            movie_data["Release date"] = numerical_date
                        else:
                            text = data.get_text(separator=" ", strip=True)
                            movie_data["Release date"] = generate_date(text)
                    else:
                        text = data.get_text(separator=" ", strip=True)
                        movie_data["Release date"] = generate_date(text)
                elif field == "Running time":
                    # Handle running time field
                    running_time_match = re.search(r'(\d{1,2}):(\d{2}):(\d{2})', text)  # e.g., 1:30:00
                    if running_time_match:
                        hours, minutes, seconds = map(int, running_time_match.groups())
                        total_minutes = hours * 60 + minutes
                        movie_data["Running time"] = total_minutes
                    else:
                        # If no "h:mm:ss" format, try to extract minutes directly (e.g., "90 min")
                        minutes_match = re.search(r'(\d+)\s*min', text)
                        if minutes_match:
                            movie_data["Running time"] = minutes_match.group(1)
                else:
                    text = list_item.get_text(separator=" ", strip=True) if list_item else data.get_text(separator=" ", strip=True)
                    movie_data[field] = text
    movies.append(movie_data)
    return movie_data


if __name__ == "__main__":
      for i in range(10, 98):
        suffix = get_suffix(i)
        url = f"https://en.wikipedia.org/wiki/{i}{suffix}_Academy_Awards"
        soup = fetch_page(url)
        if not soup:
            continue
        table = soup.find("table", class_="wikitable")
        if not table:
            continue
        tds = table.find_all("td")
        for td in tds:
            actor_links = td.select("ul > li > b > a, ul > li > a")
            for actor in actor_links:
                actor_name = actor.text.strip()
                actor_link = urljoin(base_url, actor["href"])
                if any(word in actor_link.lower() for word in ["production", "department", "artists", "prod.","(song)"]):
                    print(f"Skipping: {actor_name} (Irrelevant)")
                    continue
                actor_info = extract_actor_info(actor_name, actor_link)
                if actor_info:
                    print(f"Actor: {actor_info}")
            movie_links = td.select("ul > li > i > b > a, ul > li > i > a")
            for movie in movie_links:
                movie_name = movie.text.strip()
                movie_link = urljoin(base_url, movie["href"])
                movie_info = extract_movie_info(movie_name, movie_link)
                if movie_info:
                    print(f"Movie: {movie_info}")
# Out:
# Fetched: https://en.wikipedia.org/wiki/45th_Academy_Awards
# Fetched: https://en.wikipedia.org/wiki/Albert_S._Ruddy
# Actor: {'name': 'Albert S. Ruddy', 'DOB': '1930-03-28', 'Birth Country': 'Canada', 'DOD': '2024-05-25'}
# Fetched: https://en.wikipedia.org/wiki/Cy_Feuer
# Actor: {'name': 'Cy Feuer', 'DOB': '1911-01-15', 'Birth Country': 'U.S.', 'DOD': '2006-05-17'}
# Fetched: https://en.wikipedia.org/wiki/John_Boorman
# Actor: {'name': 'John Boorman', 'DOB': '1933-01-18', 'Birth Country': 'England', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Bengt_Forslund
# Actor: {'name': 'Bengt Forslund', 'DOB': '1932-06-22', 'Birth Country': '( 1932-06-22 ) 22 June 1932 (age\xa092)', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Robert_B._Radnitz
# infobox not found for Robert B. Radnitz - https://en.wikipedia.org/wiki/Robert_B._Radnitz
# Fetched: https://en.wikipedia.org/wiki/Cabaret_(1972_film)
# Movie: {'Name': 'Cabaret', 'Release date': '1972-02-13', 'Distributed by': 'Allied Artists', 'Language': 'English', 'Running time': '124'}
# Fetched: https://en.wikipedia.org/wiki/Deliverance
# Movie: {'Name': 'Deliverance', 'Release date': '1972-07-30', 'Distributed by': 'Warner Bros.', 'Language': 'English', 'Running time': '109'}
# Fetched: https://en.wikipedia.org/wiki/The_Emigrants_(film)
# Movie: {'Name': 'The Emigrants', 'Release date': '1971-03-08', 'Distributed by': 'Svensk Filmindustri (Scandinavia) Warner Bros. (International)', 'Language': 'Swedish', 'Running time': '192'}
# Fetched: https://en.wikipedia.org/wiki/Sounder_(film)
# Movie: {'Name': 'Sounder', 'Release date': '1972-09-24', 'Distributed by': '20th Century Fox', 'Language': 'English', 'Running time': '105'}
# Fetched: https://en.wikipedia.org/wiki/Bob_Fosse
# Actor: {'name': 'Bob Fosse', 'DOB': '1927-06-23', 'Birth Country': 'U.S.', 'DOD': '1987-09-23'}
# Skipping John Boorman- https://en.wikipedia.org/wiki/John_Boorman (already visited)
# Fetched: https://en.wikipedia.org/wiki/Jan_Troell
# Actor: {'name': 'Jan Troell', 'DOB': '1931-07-23', 'Birth Country': 'Sweden', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Francis_Ford_Coppola
# Actor: {'name': 'Francis Ford Coppola', 'DOB': '1939-04-07', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Joseph_L._Mankiewicz
# Actor: {'name': 'Joseph L. Mankiewicz', 'DOB': '1909-02-11', 'Birth Country': 'U.S.', 'DOD': '1993-02-05'}
# Skipping Deliverance- https://en.wikipedia.org/wiki/Deliverance (already visited)
# Skipping The Emigrants- https://en.wikipedia.org/wiki/The_Emigrants_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Godfather
# Movie: {'Name': 'The Godfather', 'Release date': '1972-03-14', 'Distributed by': 'Paramount Pictures', 'Language': 'English', 'Running time': '175'}
# Fetched: https://en.wikipedia.org/wiki/Sleuth_(1972_film)
# Movie: {'Name': 'Sleuth', 'Release date': '1972-12-11', 'Distributed by': '20th Century Fox', 'Language': 'English', 'Running time': '138'}
# Fetched: https://en.wikipedia.org/wiki/Marlon_Brando
# Actor: {'name': 'Marlon Brando', 'DOB': '1924-04-03', 'Birth Country': 'U.S.', 'DOD': '2004-07-01'}
# Fetched: https://en.wikipedia.org/wiki/Vito_Corleone
# Actor: {'name': 'Vito Corleone', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org#Sacheen_Littlefeather's_appearance
# infobox not found for declined - https://en.wikipedia.org#Sacheen_Littlefeather's_appearance
# Fetched: https://en.wikipedia.org/wiki/Michael_Caine
# Actor: {'name': 'Michael Caine', 'DOB': '1933-03-14', 'Birth Country': 'England', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Laurence_Olivier
# Actor: {'name': 'Laurence Olivier', 'DOB': '1907-05-22', 'Birth Country': 'England', 'DOD': '1989-07-11'}
# Fetched: https://en.wikipedia.org/wiki/Peter_O%27Toole
# Actor: {'name': "Peter O'Toole", 'DOB': '1932-08-02', 'Birth Country': 'England', 'DOD': '2013-12-14'}
# Fetched: https://en.wikipedia.org/wiki/Paul_Winfield
# Actor: {'name': 'Paul Winfield', 'DOB': '1939-05-22', 'Birth Country': 'U.S.', 'DOD': '2004-03-07'}
# Skipping Sleuth- https://en.wikipedia.org/wiki/Sleuth_(1972_film) (already visited)
# Skipping Sleuth- https://en.wikipedia.org/wiki/Sleuth_(1972_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Ruling_Class_(film)
# Movie: {'Name': 'The Ruling Class', 'Release date': '1972-09-13', 'Distributed by': 'United Artists (UK theatrical)', 'Language': 'English', 'Running time': '154'}
# Skipping Sounder- https://en.wikipedia.org/wiki/Sounder_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Liza_Minnelli
# Actor: {'name': 'Liza Minnelli', 'DOB': '1946-03-12', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Sally_Bowles
# Actor: {'name': 'Sally Bowles', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Diana_Ross
# Actor: {'name': 'Diana Ross', 'DOB': '1944-03-26', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Billie_Holiday
# Actor: {'name': 'Billie Holiday', 'DOB': '1915-04-07', 'Birth Country': 'U.S.', 'DOD': '1959-07-17'}
# Fetched: https://en.wikipedia.org/wiki/Maggie_Smith
# Actor: {'name': 'Maggie Smith', 'DOB': '1934-12-28', 'Birth Country': 'England', 'DOD': '2024-09-27'}
# Fetched: https://en.wikipedia.org/wiki/Cicely_Tyson
# Actor: {'name': 'Cicely Tyson', 'DOB': '1924-12-19', 'Birth Country': 'U.S.', 'DOD': '2021-01-28'}
# Fetched: https://en.wikipedia.org/wiki/Liv_Ullmann
# Actor: {'name': 'Liv Ullmann', 'DOB': '1938-12-16', 'Birth Country': 'Japan', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Lady_Sings_the_Blues_(film)
# Movie: {'Name': 'Lady Sings the Blues', 'Release date': '1972-10-12', 'Distributed by': 'Paramount Pictures', 'Language': 'English', 'Running time': '144'}
# Fetched: https://en.wikipedia.org/wiki/Travels_with_My_Aunt_(film)
# Movie: {'Name': 'Travels with My Aunt', 'Release date': '1972-12-17', 'Distributed by': 'Metro-Goldwyn-Mayer', 'Language': 'English', 'Running time': '109'}
# Skipping Sounder- https://en.wikipedia.org/wiki/Sounder_(film) (already visited)
# Skipping The Emigrants- https://en.wikipedia.org/wiki/The_Emigrants_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Joel_Grey
# Actor: {'name': 'Joel Grey', 'DOB': '1932-04-11', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/M.C.
# infobox not found for M.C. - https://en.wikipedia.org/wiki/M.C.
# Fetched: https://en.wikipedia.org/wiki/Eddie_Albert
# Actor: {'name': 'Eddie Albert', 'DOB': '1906-04-22', 'Birth Country': 'U.S.', 'DOD': '2005-05-26'}
# Fetched: https://en.wikipedia.org/wiki/James_Caan
# Actor: {'name': 'James Caan', 'DOB': '1940-03-26', 'Birth Country': 'U.S.', 'DOD': '2022-07-06'}
# Fetched: https://en.wikipedia.org/wiki/Sonny_Corleone
# Actor: {'name': 'Santino "Sonny" Corleone', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Robert_Duvall
# Actor: {'name': 'Robert Duvall', 'DOB': '1931-01-05', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Tom_Hagen
# Actor: {'name': 'Tom Hagen', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Al_Pacino
# Actor: {'name': 'Al Pacino', 'DOB': '1940-04-25', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Michael_Corleone
# Actor: {'name': 'Michael Corleone', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/The_Heartbreak_Kid_(1972_film)
# Movie: {'Name': 'The Heartbreak Kid', 'Release date': '1972-12-17', 'Distributed by': '20th Century Fox', 'Language': 'English', 'Running time': '106'}
# Skipping The Godfather- https://en.wikipedia.org/wiki/The_Godfather (already visited)
# Skipping The Godfather- https://en.wikipedia.org/wiki/The_Godfather (already visited)
# Skipping The Godfather- https://en.wikipedia.org/wiki/The_Godfather (already visited)
# Fetched: https://en.wikipedia.org/wiki/Eileen_Heckart
# Actor: {'name': 'Eileen Heckart', 'DOB': '1919-03-29', 'Birth Country': 'U.S.', 'DOD': '2001-12-31'}
# Fetched: https://en.wikipedia.org/wiki/Jeannie_Berlin
# Actor: {'name': 'Jeannie Berlin', 'DOB': '1949-11-01', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Geraldine_Page
# Actor: {'name': 'Geraldine Page', 'DOB': '1924-11-22', 'Birth Country': 'U.S.', 'DOD': '1987-06-13'}
# Fetched: https://en.wikipedia.org/wiki/Susan_Tyrrell
# Actor: {'name': 'Susan Tyrrell', 'DOB': '1945-03-18', 'Birth Country': 'U.S.', 'DOD': '2012-06-16'}
# Fetched: https://en.wikipedia.org/wiki/Shelley_Winters
# Actor: {'name': 'Shelley Winters', 'DOB': '1920-08-18', 'Birth Country': 'U.S.', 'DOD': '2006-01-14'}
# Skipping The Heartbreak Kid- https://en.wikipedia.org/wiki/The_Heartbreak_Kid_(1972_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Pete_%27n%27_Tillie
# Movie: {'Name': "Pete 'n' Tillie", 'Release date': '1972-12-17', 'Distributed by': 'Universal Pictures', 'Language': 'English', 'Running time': '100'}
# Fetched: https://en.wikipedia.org/wiki/Fat_City_(film)
# Movie: {'Name': 'Fat City', 'Release date': '1972-07-26', 'Distributed by': 'Columbia Pictures', 'Language': 'English', 'Running time': '97'}
# Fetched: https://en.wikipedia.org/wiki/The_Poseidon_Adventure_(1972_film)
# Movie: {'Name': 'The Poseidon Adventure', 'Release date': '1972-12-12', 'Distributed by': '20th Century Fox', 'Language': 'English', 'Running time': '117'}
# Fetched: https://en.wikipedia.org/wiki/Jeremy_Larner
# infobox not found for Jeremy Larner - https://en.wikipedia.org/wiki/Jeremy_Larner
# Fetched: https://en.wikipedia.org/wiki/Luis_Bu%C3%B1uel
# Actor: {'name': 'Luis Buñuel', 'DOB': '1900-02-22', 'Birth Country': 'Spain', 'DOD': '1983-07-29'}
# Fetched: https://en.wikipedia.org/wiki/Jean-Claude_Carri%C3%A8re
# Actor: {'name': 'Jean-Claude Carrière', 'DOB': '1931-09-17', 'Birth Country': 'France', 'DOD': '2021-02-08'}
# Fetched: https://en.wikipedia.org/wiki/Chris_Clark_(singer)
# Actor: {'name': 'Chris Clark', 'DOB': '1946-02-01', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Suzanne_de_Passe
# Actor: {'name': 'Suzanne de Passe', 'DOB': '1946-07-19', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Louis_Malle
# Actor: {'name': 'Louis Malle', 'DOB': '1932-10-30', 'Birth Country': 'France', 'DOD': '1995-11-23'}
# Fetched: https://en.wikipedia.org/wiki/Carl_Foreman
# Actor: {'name': 'Carl Foreman', 'DOB': '1914-07-23', 'Birth Country': 'U.S.', 'DOD': '1984-06-26'}
# Fetched: https://en.wikipedia.org/wiki/The_Discreet_Charm_of_the_Bourgeoisie
# Movie: {'Name': 'The Discreet Charm of the Bourgeoisie', 'Release date': '1972-09-15', 'Distributed by': '20th Century Fox', 'Language': 'N/A', 'Running time': '101'}
# Skipping Lady Sings the Blues- https://en.wikipedia.org/wiki/Lady_Sings_the_Blues_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Murmur_of_the_Heart
# Movie: {'Name': 'Murmur of the Heart', 'Release date': '1971-04-28', 'Distributed by': 'Cinema International Corporation', 'Language': 'French', 'Running time': '118'}
# Fetched: https://en.wikipedia.org/wiki/Young_Winston
# Movie: {'Name': 'Young Winston', 'Release date': '1972-07-28', 'Distributed by': 'Columbia Pictures (through Columbia - Warner Distributors )', 'Language': 'English', 'Running time': '157'}
# Skipping Francis Ford Coppola- https://en.wikipedia.org/wiki/Francis_Ford_Coppola (already visited)
# Fetched: https://en.wikipedia.org/wiki/Mario_Puzo
# Actor: {'name': 'Mario Puzo', 'DOB': '1920-10-15', 'Birth Country': 'U.S.', 'DOD': '1999-07-02'}
# Fetched: https://en.wikipedia.org/wiki/The_Godfather_(novel)
# Actor: {'name': 'the novel', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Jay_Presson_Allen
# Actor: {'name': 'Jay Presson Allen', 'DOB': '1922-03-03', 'Birth Country': 'U.S.', 'DOD': '2006-05-01'}
# Fetched: https://en.wikipedia.org/wiki/Cabaret_(musical)
# Actor: {'name': 'the musical', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Fred_Ebb
# Actor: {'name': 'Fred Ebb', 'DOB': '1928-04-08', 'Birth Country': 'U.S.', 'DOD': '2004-09-11'}
# Fetched: https://en.wikipedia.org/wiki/John_Kander
# Actor: {'name': 'John Kander', 'DOB': '1927-03-18', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Joe_Masteroff
# infobox not found for Joe Masteroff - https://en.wikipedia.org/wiki/Joe_Masteroff
# Skipping Bengt Forslund- https://en.wikipedia.org/wiki/Bengt_Forslund (already visited)
# Skipping Jan Troell- https://en.wikipedia.org/wiki/Jan_Troell (already visited)
# Fetched: https://en.wikipedia.org/wiki/Vilhelm_Moberg
# Actor: {'name': 'Vilhelm Moberg', 'DOB': '1898-08-20', 'Birth Country': 'Sweden', 'DOD': '1973-08-08'}
# Fetched: https://en.wikipedia.org/wiki/Julius_J._Epstein
# Actor: {'name': 'Julius J. Epstein', 'DOB': '1909-08-22', 'Birth Country': 'U.S.', 'DOD': '2000-12-30'}
# Fetched: https://en.wikipedia.org/wiki/Peter_De_Vries
# Actor: {'name': 'Peter De Vries', 'DOB': '1910-02-27', 'Birth Country': 'US', 'DOD': '1993-09-28'}
# Fetched: https://en.wikipedia.org/wiki/Lonne_Elder_III
# Actor: {'name': 'Lonne Elder III', 'DOB': '1927-12-26', 'Birth Country': 'United States', 'DOD': '1996-06-11'}
# Fetched: https://en.wikipedia.org/wiki/Sounder_(novel)
# Actor: {'name': 'the novel', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/William_H._Armstrong_(author)
# Actor: {'name': 'William H. Armstrong', 'DOB': '1911-09-14', 'Birth Country': 'US', 'DOD': '1999-04-11'}
# Skipping Cabaret- https://en.wikipedia.org/wiki/Cabaret_(1972_film) (already visited)
# Skipping The Emigrants- https://en.wikipedia.org/wiki/The_Emigrants_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Emigrants_(Swedish_novel)
# Movie: {'Name': 'The Emigrants', 'Release date': 'N/A', 'Distributed by': 'N/A', 'Language': 'Swedish', 'Running time': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Unto_a_Good_Land
# Movie: {'Name': 'Unto a Good Land', 'Release date': 'N/A', 'Distributed by': 'N/A', 'Language': 'Swedish', 'Running time': 'N/A'}
# Skipping Pete 'n' Tillie- https://en.wikipedia.org/wiki/Pete_%27n%27_Tillie (already visited)
# Skipping Sounder- https://en.wikipedia.org/wiki/Sounder_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/List_of_French_submissions_for_the_Academy_Award_for_Best_Foreign_Language_Film
# Actor: {'name': 'France', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/French_language
# Actor: {'name': 'French', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Skipping Luis Buñuel- https://en.wikipedia.org/wiki/Luis_Bu%C3%B1uel (already visited)
# Fetched: https://en.wikipedia.org/wiki/List_of_Russian_submissions_for_the_Academy_Award_for_Best_Foreign_Language_Film
# Actor: {'name': 'USSR', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Russian_language
# Actor: {'name': 'Russian', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Stanislav_Rostotsky
# Actor: {'name': 'Stanislav Rostotsky', 'DOB': '1922-04-21', 'Birth Country': 'Russian SFSR', 'DOD': '2001-08-10'}
# Fetched: https://en.wikipedia.org/wiki/List_of_Israeli_submissions_for_the_Academy_Award_for_Best_Foreign_Language_Film
# Actor: {'name': 'Israel', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Hebrew_language
# Actor: {'name': 'Hebrew', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Mosh%C3%A9_Mizrahi
# Actor: {'name': 'Moshé Mizrahi', 'DOB': '1931-09-05', 'Birth Country': 'Egypt', 'DOD': '2018-08-03'}
# Fetched: https://en.wikipedia.org/wiki/List_of_Spanish_submissions_for_the_Academy_Award_for_Best_Foreign_Language_Film
# Actor: {'name': 'Spain', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Spanish_language
# Actor: {'name': 'Spanish', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Jaime_de_Armi%C3%B1%C3%A1n
# Actor: {'name': 'Jaime de Armiñán', 'DOB': '1927-03-09', 'Birth Country': 'Spain', 'DOD': '2024-04-09'}
# Fetched: https://en.wikipedia.org/wiki/List_of_Swedish_submissions_for_the_Academy_Award_for_Best_Foreign_Language_Film
# Actor: {'name': 'Sweden', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Swedish_language
# Actor: {'name': 'Swedish', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Skipping Jan Troell- https://en.wikipedia.org/wiki/Jan_Troell (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Dawns_Here_Are_Quiet_(1972_film)
# Movie: {'Name': 'The Dawns Here Are Quiet', 'Release date': '1972 ( 1972 )', 'Distributed by': 'N/A', 'Language': 'Russian', 'Running time': '188'}
# Fetched: https://en.wikipedia.org/wiki/I_Love_You_Rosa
# Movie: {'Name': 'I Love You Rosa', 'Release date': '1972 ( 1972 )', 'Distributed by': 'N/A', 'Language': 'Hebrew', 'Running time': '92'}
# Fetched: https://en.wikipedia.org/wiki/My_Dearest_Senorita
# Movie: {'Name': 'My Dearest Senorita', 'Release date': '1972-02-17', 'Distributed by': 'N/A', 'Language': 'Spanish', 'Running time': '80'}
# Fetched: https://en.wikipedia.org/wiki/The_New_Land_(1972_film)
# Movie: {'Name': 'The New Land', 'Release date': '1972-02-26', 'Distributed by': 'Svensk Filmindustri (Scandinavia) Warner Bros. (International)', 'Language': 'Swedish', 'Running time': '202'}
# Fetched: https://en.wikipedia.org/wiki/Sarah_Kernochan
# Actor: {'name': 'Sarah Kernochan', 'DOB': '1947-12-30', 'Birth Country': '1947 (age\xa077) New York City', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Howard_Smith_(director)
# Actor: {'name': 'Howard Smith', 'DOB': '1936-12-10', 'Birth Country': 'U.S.', 'DOD': '2014-05-01'}
# Fetched: https://en.wikipedia.org/wiki/Bert_Haanstra
# Actor: {'name': 'Bert Haanstra', 'DOB': '1916-05-31', 'Birth Country': 'Netherlands', 'DOD': '1997-10-23'}
# Fetched: https://en.wikipedia.org/wiki/Arnold_Perl
# Actor: {'name': 'Arnold Perl', 'DOB': '1914-04-14', 'Birth Country': '1914', 'DOD': '1971-12-11'}
# Fetched: https://en.wikipedia.org/wiki/List_of_posthumous_Academy_Award_winners_and_nominees
# infobox not found for posthumously - https://en.wikipedia.org/wiki/List_of_posthumous_Academy_Award_winners_and_nominees
# Fetched: https://en.wikipedia.org/wiki/Marvin_Worth
# Actor: {'name': 'Marvin Worth', 'DOB': '1925-06-06', 'Birth Country': 'New York', 'DOD': '1998-04-22'}
# Fetched: https://en.wikipedia.org/wiki/Robert_Hendrickson_(director)
# Actor: {'name': 'Robert Hendrickson', 'DOB': '1944-09-17', 'Birth Country': 'California', 'DOD': '2016-10-01'}
# Fetched: https://en.wikipedia.org/wiki/Laurence_Merrick
# Actor: {'name': 'Laurence Merrick', 'DOB': '1926-04-22', 'Birth Country': 'Israel', 'DOD': '1977-01-26'}
# Fetched: https://en.wikipedia.org/wiki/Ape_and_Super-Ape
# Movie: {'Name': 'Ape and Super-Ape', 'Release date': '1972 ( 1972 )', 'Distributed by': 'Ministry of Culture, Recreation and Social Welfare', 'Language': 'Dutch', 'Running time': '104'}
# Fetched: https://en.wikipedia.org/wiki/Malcolm_X_(1972_film)
# Movie: {'Name': 'Malcolm X', 'Release date': '1972-05-24', 'Distributed by': 'Warner Bros.', 'Language': 'English', 'Running time': '91'}
# Fetched: https://en.wikipedia.org/wiki/Manson_(film)
# Movie: {'Name': 'Manson', 'Release date': 'January\xa01973 ( 1973-01 )', 'Distributed by': 'American International Pictures', 'Language': 'English', 'Running time': '83'}
# Fetched: https://en.wikipedia.org/wiki/The_Silent_Revolution_(1972_film)
# Movie: {'Name': 'The Silent Revolution', 'Release date': '1972 ( 1972 )', 'Distributed by': 'N/A', 'Language': 'N/A', 'Running time': '44'}
# Fetched: https://en.wikipedia.org/wiki/Peter_Schamoni
# Actor: {'name': 'Peter Schamoni', 'DOB': '1934-03-27', 'Birth Country': 'Germany', 'DOD': '2011-06-14'}
# Fetched: https://en.wikipedia.org/wiki/Hundertwasser%27s_Rainy_Day
# Movie: {'Name': "Hundertwasser's Rainy Day", 'Release date': '1972 ( 1972 )', 'Distributed by': 'Peter Schamoni Filmproduktion', 'Language': 'German', 'Running time': '43'}
# Fetched: https://en.wikipedia.org/wiki/K-Z
# Movie: {'Name': 'K-Z', 'Release date': '1972 ( 1972 )', 'Distributed by': 'N/A', 'Language': 'Italian', 'Running time': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Selling_Out_(film)
# Movie: {'Name': 'Selling Out', 'Release date': '1972 ( 1972 )', 'Distributed by': 'Humber College', 'Language': 'English', 'Running time': '32'}
# Fetched: https://en.wikipedia.org/wiki/The_Tide_of_Traffic
# Movie: {'Name': 'The Tide of Traffic', 'Release date': '1972 ( 1972 )', 'Distributed by': 'BP', 'Language': 'English', 'Running time': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Richard_Williams_(animator)
# Actor: {'name': 'Richard Williams', 'DOB': '1933-03-19', 'Birth Country': 'Canada', 'DOD': '2019-08-16'}
# Fetched: https://en.wikipedia.org/wiki/Bob_Godfrey
# Actor: {'name': 'Bob Godfrey', 'DOB': '1921-05-27', 'Birth Country': 'New South Wales', 'DOD': '2013-02-21'}
# Fetched: https://en.wikipedia.org/wiki/Tup_Tup
# Movie: {'Name': 'Tup Tup', 'Release date': '1972-01-01', 'Distributed by': 'N/A', 'Language': 'none', 'Running time': '10'}
# Fetched: https://en.wikipedia.org/wiki/Charlie_Chaplin
# Actor: {'name': 'Charlie Chaplin', 'DOB': '1889-04-16', 'Birth Country': 'England', 'DOD': '1977-12-25'}
# Fetched: https://en.wikipedia.org/wiki/Raymond_Rasch
# Actor: {'name': 'Raymond Rasch', 'DOB': '1917-03-01', 'Birth Country': 'United States', 'DOD': '1964-12-23'}
# Skipping posthumously- https://en.wikipedia.org/wiki/List_of_posthumous_Academy_Award_winners_and_nominees (already visited)
# Skipping posthumously- https://en.wikipedia.org/wiki/List_of_posthumous_Academy_Award_winners_and_nominees (already visited)
# Fetched: https://en.wikipedia.org/wiki/John_Williams
# Actor: {'name': 'John Williams', 'DOB': '1932-02-08', 'Birth Country': '1932 (age\xa093)', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Buddy_Baker_(composer)
# Actor: {'name': 'Buddy Baker', 'DOB': '1918-01-04', 'Birth Country': 'U.S.', 'DOD': '2002-07-26'}
# Skipping John Williams- https://en.wikipedia.org/wiki/John_Williams (already visited)
# Fetched: https://en.wikipedia.org/wiki/John_Addison
# Actor: {'name': 'John Addison', 'DOB': '1920-03-16', 'Birth Country': 'England', 'DOD': '1998-12-07'}
# Fetched: https://en.wikipedia.org/wiki/Images_(film)
# Movie: {'Name': 'Images', 'Release date': '1972-05-09', 'Distributed by': 'Columbia Pictures (U.S.) Hemdale Film Distributors (U.K.)', 'Language': 'English', 'Running time': '101'}
# Fetched: https://en.wikipedia.org/wiki/Napoleon_and_Samantha
# Movie: {'Name': 'Napoleon and Samantha', 'Release date': '1972-07-05', 'Distributed by': 'Buena Vista Distribution', 'Language': 'English', 'Running time': '92'}
# Skipping The Poseidon Adventure- https://en.wikipedia.org/wiki/The_Poseidon_Adventure_(1972_film) (already visited)
# Skipping Sleuth- https://en.wikipedia.org/wiki/Sleuth_(1972_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Ralph_Burns
# Actor: {'name': 'Ralph Burns', 'DOB': '1922-06-29', 'Birth Country': 'U.S.', 'DOD': '2001-11-21'}
# Fetched: https://en.wikipedia.org/wiki/Laurence_Rosenthal
# Actor: {'name': 'Laurence Rosenthal', 'DOB': '1926-11-04', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping Lady Sings the Blues- https://en.wikipedia.org/wiki/Lady_Sings_the_Blues_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Man_of_La_Mancha_(film)
# Movie: {'Name': 'Man of La Mancha', 'Release date': '1972-12-11', 'Distributed by': 'United Artists', 'Language': 'English', 'Running time': '132'}
# Fetched: https://en.wikipedia.org/wiki/The_Morning_After_(Maureen_McGovern_song)
# Actor: {'name': 'The Morning After', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Joel_Hirschhorn
# infobox not found for Joel Hirschhorn - https://en.wikipedia.org/wiki/Joel_Hirschhorn
# Fetched: https://en.wikipedia.org/wiki/Al_Kasha
# Actor: {'name': 'Al Kasha', 'DOB': '1937-01-22', 'Birth Country': 'U.S.', 'DOD': '2020-09-14'}
# Skipping: Ben (Irrelevant)
# Fetched: https://en.wikipedia.org/wiki/Walter_Scharf
# Actor: {'name': 'Walter Scharf', 'DOB': '1910-08-01', 'Birth Country': 'U.S.', 'DOD': '2003-02-24'}
# Fetched: https://en.wikipedia.org/wiki/Don_Black_(lyricist)
# Actor: {'name': 'Don Black', 'DOB': '1938-06-21', 'Birth Country': 'England', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Fred_Karlin
# Actor: {'name': 'Fred Karlin', 'DOB': '1936-06-16', 'Birth Country': 'U.S.', 'DOD': '2004-03-26'}
# Fetched: https://en.wikipedia.org/wiki/Maurice_Jarre
# Actor: {'name': 'Maurice Jarre', 'DOB': '1924-09-13', 'Birth Country': 'France', 'DOD': '2009-03-28'}
# Fetched: https://en.wikipedia.org/wiki/Alan_and_Marilyn_Bergman
# Actor: {'name': 'Alan and Marilyn Bergman', 'DOB': '1925-09-11', 'Birth Country': 'U.S.', 'DOD': '2022-01-08'}
# Fetched: https://en.wikipedia.org/wiki/Sammy_Fain
# Actor: {'name': 'Sammy Fain', 'DOB': '1902-06-17', 'Birth Country': 'United States', 'DOD': '1989-12-06'}
# Fetched: https://en.wikipedia.org/wiki/Paul_Francis_Webster
# Actor: {'name': 'Paul Francis Webster', 'DOB': '1907-12-20', 'Birth Country': 'United States', 'DOD': '1984-03-18'}
# Fetched: https://en.wikipedia.org/wiki/Ben_(1972_film)
# Movie: {'Name': 'Ben', 'Release date': '1972-06-23', 'Distributed by': 'Cinerama Releasing Corporation', 'Language': 'English', 'Running time': '94'}
# Fetched: https://en.wikipedia.org/wiki/The_Little_Ark
# Movie: {'Name': 'The Little Ark', 'Release date': 'March\xa01972 ( 1972-03 )', 'Distributed by': 'National General Pictures', 'Language': 'English', 'Running time': '100'}
# Fetched: https://en.wikipedia.org/wiki/The_Life_and_Times_of_Judge_Roy_Bean
# Movie: {'Name': 'The Life and Times of Judge Roy Bean', 'Release date': '1972-12-18', 'Distributed by': 'National General Pictures', 'Language': 'English', 'Running time': '120'}
# Fetched: https://en.wikipedia.org/wiki/The_Stepmother_(1972_film)
# Movie: {'Name': 'The Stepmother', 'Release date': 'March\xa01972 ( 1972-03 )', 'Distributed by': 'N/A', 'Language': 'English', 'Running time': '94'}
# Fetched: https://en.wikipedia.org/wiki/Anthony_Powell_(designer)
# Actor: {'name': 'Anthony Powell', 'DOB': '1935-06-02', 'Birth Country': 'England', 'DOD': '2021-04-16'}
# Fetched: https://en.wikipedia.org/wiki/Anna_Hill_Johnstone
# Actor: {'name': 'Anna Hill Johnstone', 'DOB': '1913-04-07', 'Birth Country': 'U.S.', 'DOD': '1992-10-16'}
# Fetched: https://en.wikipedia.org/wiki/Ray_Aghayan
# Actor: {'name': 'Ray Aghayan', 'DOB': '1928-07-28', 'Birth Country': 'Iran', 'DOD': '2011-10-10'}
# Fetched: https://en.wikipedia.org/wiki/Norma_Koch
# Actor: {'name': 'Norma Koch', 'DOB': '1898-03-27', 'Birth Country': '1898', 'DOD': '1979-07-29'}
# Fetched: https://en.wikipedia.org/wiki/Bob_Mackie
# Actor: {'name': 'Bob Mackie', 'DOB': '1939-03-24', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Paul_Zastupnevich
# Actor: {'name': 'Paul Zastupnevich', 'DOB': '1921-12-24', 'Birth Country': 'Pennsylvania', 'DOD': '1997-05-09'}
# Fetched: https://en.wikipedia.org/wiki/Anthony_Mendleson
# infobox not found for Anthony Mendleson - https://en.wikipedia.org/wiki/Anthony_Mendleson
# Skipping The Godfather- https://en.wikipedia.org/wiki/The_Godfather (already visited)
# Skipping Lady Sings the Blues- https://en.wikipedia.org/wiki/Lady_Sings_the_Blues_(film) (already visited)
# Skipping The Poseidon Adventure- https://en.wikipedia.org/wiki/The_Poseidon_Adventure_(1972_film) (already visited)
# Skipping Young Winston- https://en.wikipedia.org/wiki/Young_Winston (already visited)
# Fetched: https://en.wikipedia.org/wiki/David_Hildyard
# Actor: {'name': 'David Hildyard', 'DOB': '1916-05-15', 'Birth Country': 'England', 'DOD': '2008-02-19'}
# Fetched: https://en.wikipedia.org/wiki/Robert_Knudson
# Actor: {'name': 'Robert Knudson', 'DOB': '1925-09-29', 'Birth Country': 'United States', 'DOD': '2006-01-21'}
# Fetched: https://en.wikipedia.org/wiki/Charles_T._Knight
# Actor: {'name': 'Charles T. Knight', 'DOB': '1931-10-18', 'Birth Country': '1931', 'DOD': '2023-06-29'}
# Fetched: https://en.wikipedia.org/wiki/Arthur_Piantadosi
# Actor: {'name': 'Arthur Piantadosi', 'DOB': '1916-11-04', 'Birth Country': 'New York', 'DOD': '1994-02-23'}
# Fetched: https://en.wikipedia.org/wiki/Gene_Cantamessa
# Actor: {'name': 'Gene Cantamessa', 'DOB': '1931-02-17', 'Birth Country': 'United States', 'DOD': '2011-11-08'}
# Fetched: https://en.wikipedia.org/wiki/Richard_Portman
# Actor: {'name': 'Richard Portman', 'DOB': '1934-04-02', 'Birth Country': 'United States', 'DOD': '2017-01-28'}
# Fetched: https://en.wikipedia.org/wiki/Charles_Grenzbach
# Actor: {'name': 'Bud Grenzbach', 'DOB': '1923-12-29', 'Birth Country': 'United States', 'DOD': '2004-03-29'}
# Fetched: https://en.wikipedia.org/wiki/Chris_Newman_(sound_engineer)
# Actor: {'name': 'Christopher Newman', 'DOB': '1940-02-17', 'Birth Country': 'U.S.', 'DOD': '2025-02-03'}
# Skipping Richard Portman- https://en.wikipedia.org/wiki/Richard_Portman (already visited)
# Fetched: https://en.wikipedia.org/wiki/Herman_Lewis
# Actor: {'name': 'Herman Lewis', 'DOB': '1910-11-10', 'Birth Country': '1910', 'DOD': '2001-02-28'}
# Fetched: https://en.wikipedia.org/wiki/Theodore_Soderberg_(1923%E2%80%932012)
# Actor: {'name': 'Theodore Soderberg', 'DOB': '1923-01-08', 'Birth Country': 'U.S.', 'DOD': '2012-11-15'}
# Fetched: https://en.wikipedia.org/wiki/Butterflies_Are_Free
# Movie: {'Name': 'Butterflies Are Free', 'Release date': '1972-07-06', 'Distributed by': 'Columbia Pictures', 'Language': 'English', 'Running time': '109'}
# Fetched: https://en.wikipedia.org/wiki/The_Candidate_(1972_film)
# Movie: {'Name': 'The Candidate', 'Release date': '1972-06-29', 'Distributed by': 'Warner Bros.', 'Language': 'English', 'Running time': '109'}
# Skipping The Godfather- https://en.wikipedia.org/wiki/The_Godfather (already visited)
# Skipping The Poseidon Adventure- https://en.wikipedia.org/wiki/The_Poseidon_Adventure_(1972_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Hans_J%C3%BCrgen_Kiebach
# Actor: {'name': 'Hans Jürgen Kiebach', 'DOB': '1930-08-28', 'Birth Country': '( 1930-08-28 ) 28 August 1930', 'DOD': '1995-05-19'}
# Fetched: https://en.wikipedia.org/wiki/Rolf_Zehetbauer
# Actor: {'name': 'Rolf Zehetbauer', 'DOB': '1929-02-13', 'Birth Country': 'Germany', 'DOD': '2022-01-23'}
# Fetched: https://en.wikipedia.org/wiki/Herbert_Strabel
# Actor: {'name': 'Herbert Strabel', 'DOB': '1927-10-14', 'Birth Country': 'Germany', 'DOD': '2017-10-21'}
# Fetched: https://en.wikipedia.org/wiki/Carl_Anderson_(art_director)
# Actor: {'name': 'Carl Anderson', 'DOB': '1903-06-13', 'Birth Country': 'New Jersey', 'DOD': '1989-09-22'}
# Fetched: https://en.wikipedia.org/wiki/Reg_Allen_(set_decorator)
# Actor: {'name': 'Reg Allen', 'DOB': '1917-04-12', 'Birth Country': 'England', 'DOD': '1989-03-30'}
# Fetched: https://en.wikipedia.org/wiki/William_J._Creber
# Actor: {'name': 'William Creber', 'DOB': '1931-07-26', 'Birth Country': 'U.S.', 'DOD': '2019-03-07'}
# Fetched: https://en.wikipedia.org/wiki/Rapha%C3%ABl_Bretton
# Actor: {'name': 'Raphaël Bretton', 'DOB': '1920-02-07', 'Birth Country': 'France', 'DOD': '2011-02-20'}
# Fetched: https://en.wikipedia.org/wiki/John_Box
# infobox not found for John Box - https://en.wikipedia.org/wiki/John_Box
# Fetched: https://en.wikipedia.org/wiki/Robert_W._Laing
# Actor: {'name': 'Robert W. Laing', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Gil_Parrondo
# Actor: {'name': 'Gil Parrondo', 'DOB': '1921-06-17', 'Birth Country': 'Spain', 'DOD': '2016-12-24'}
# Fetched: https://en.wikipedia.org/wiki/Donald_M._Ashton
# Actor: {'name': 'Donald M. Ashton', 'DOB': '1919-06-26', 'Birth Country': 'England', 'DOD': '2004-08-25'}
# Fetched: https://en.wikipedia.org/wiki/Geoffrey_Drake
# Actor: {'name': 'Geoffrey Drake', 'DOB': '1911', 'Birth Country': '1911', 'DOD': '1995 (aged\xa083–84)'}
# Fetched: https://en.wikipedia.org/wiki/John_Graysmark
# Actor: {'name': 'John Graysmark', 'DOB': '1935-03-26', 'Birth Country': '( 1935-03-26 ) 26 March 1935', 'DOD': '2010-10-10'}
# Fetched: https://en.wikipedia.org/wiki/William_Hutchinson_(art_director)
# Actor: {'name': 'William Hutchinson', 'DOB': 'William Ronald Hutchinson 14 August 1901 [ 1 ] Skipton , Yorkshire', 'Birth Country': 'Yorkshire', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Peter_James_(set_decorator)
# Actor: {'name': 'Peter James', 'DOB': '1924-04-14', 'Birth Country': '( 1924-04-14 ) 14 April 1924', 'DOD': '1997-11-17'}
# Skipping Lady Sings the Blues- https://en.wikipedia.org/wiki/Lady_Sings_the_Blues_(film) (already visited)
# Skipping The Poseidon Adventure- https://en.wikipedia.org/wiki/The_Poseidon_Adventure_(1972_film) (already visited)
# Skipping Travels with My Aunt- https://en.wikipedia.org/wiki/Travels_with_My_Aunt_(film) (already visited)
# Skipping Young Winston- https://en.wikipedia.org/wiki/Young_Winston (already visited)
# Fetched: https://en.wikipedia.org/wiki/Geoffrey_Unsworth
# Actor: {'name': 'Geoffrey Unsworth', 'DOB': '1914-05-26', 'Birth Country': 'England', 'DOD': '1978-10-28'}
# Fetched: https://en.wikipedia.org/wiki/Harry_Stradling_Jr.
# Actor: {'name': 'Harry Stradling Jr.', 'DOB': '1925-01-07', 'Birth Country': 'New York', 'DOD': '2017-10-17'}
# Fetched: https://en.wikipedia.org/wiki/Charles_Lang
# Actor: {'name': 'Charles Lang', 'DOB': '1902-03-27', 'Birth Country': 'U.S.', 'DOD': '1998-04-03'}
# Fetched: https://en.wikipedia.org/wiki/Douglas_Slocombe
# Actor: {'name': 'Douglas Slocombe', 'DOB': '1913-02-10', 'Birth Country': 'UK', 'DOD': '2016-02-22'}
# Fetched: https://en.wikipedia.org/wiki/1776_(film)
# Movie: {'Name': '1776', 'Release date': '1972-11-17', 'Distributed by': 'Columbia Pictures', 'Language': 'English', 'Running time': '177'}
# Skipping Butterflies Are Free- https://en.wikipedia.org/wiki/Butterflies_Are_Free (already visited)
# Skipping The Poseidon Adventure- https://en.wikipedia.org/wiki/The_Poseidon_Adventure_(1972_film) (already visited)
# Skipping Travels with My Aunt- https://en.wikipedia.org/wiki/Travels_with_My_Aunt_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/David_Bretherton
# Actor: {'name': 'David Bretherton', 'DOB': '1924-02-29', 'Birth Country': 'United States', 'DOD': '2000-05-11'}
# Fetched: https://en.wikipedia.org/wiki/Tom_Priestley
# Actor: {'name': 'Tom Priestley', 'DOB': '1932-04-22', 'Birth Country': 'England', 'DOD': '2023-12-25'}
# Fetched: https://en.wikipedia.org/wiki/William_Reynolds_(film_editor)
# Actor: {'name': 'William H. Reynolds', 'DOB': '1910-06-14', 'Birth Country': 'U.S.', 'DOD': '1997-07-16'}
# Fetched: https://en.wikipedia.org/wiki/Peter_Zinner
# Actor: {'name': 'Peter Zinner', 'DOB': '1919-07-24', 'Birth Country': 'Austria', 'DOD': '2007-11-13'}
# Fetched: https://en.wikipedia.org/wiki/Fred_W._Berger
# Actor: {'name': 'Fred W. Berger', 'DOB': '1908-07-09', 'Birth Country': 'U.S.', 'DOD': '2003-05-23'}
# Fetched: https://en.wikipedia.org/wiki/Frank_P._Keller
# Actor: {'name': 'Frank P. Keller', 'DOB': '1913-02-04', 'Birth Country': '1913 Pennsylvania', 'DOD': '1977-12-25'}
# Fetched: https://en.wikipedia.org/wiki/Harold_F._Kress
# Actor: {'name': 'Harold F. Kress', 'DOB': '1913-06-26', 'Birth Country': 'U.S.', 'DOD': '1999-09-18'}
# Skipping Deliverance- https://en.wikipedia.org/wiki/Deliverance (already visited)
# Skipping The Godfather- https://en.wikipedia.org/wiki/The_Godfather (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Hot_Rock_(film)
# Movie: {'Name': 'The Hot Rock', 'Release date': '1972-01-26', 'Distributed by': '20th Century Fox', 'Language': 'English', 'Running time': '105'}
# Skipping The Poseidon Adventure- https://en.wikipedia.org/wiki/The_Poseidon_Adventure_(1972_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/46th_Academy_Awards
# Fetched: https://en.wikipedia.org/wiki/Tony_Bill
# Actor: {'name': 'Tony Bill', 'DOB': '1940-08-23', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Julia_Phillips
# Actor: {'name': 'Julia Phillips', 'DOB': '1944-04-07', 'Birth Country': 'U.S.', 'DOD': '2002-01-01'}
# Fetched: https://en.wikipedia.org/wiki/Michael_Phillips_(producer)
# Actor: {'name': 'Michael Phillips', 'DOB': '1943-06-29', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping Francis Ford Coppola- https://en.wikipedia.org/wiki/Francis_Ford_Coppola (already visited)
# Fetched: https://en.wikipedia.org/wiki/Gary_Kurtz
# Actor: {'name': 'Gary Kurtz', 'DOB': '1940-07-27', 'Birth Country': 'U.S.', 'DOD': '2018-09-23'}
# Fetched: https://en.wikipedia.org/wiki/Ingmar_Bergman
# Actor: {'name': 'Ingmar Bergman', 'DOB': '1918-07-14', 'Birth Country': 'Sweden', 'DOD': '2007-07-30'}
# Fetched: https://en.wikipedia.org/wiki/William_Peter_Blatty
# Actor: {'name': 'William Peter Blatty', 'DOB': '1928-01-07', 'Birth Country': 'U.S.', 'DOD': '2017-01-12'}
# Fetched: https://en.wikipedia.org/wiki/Melvin_Frank
# Actor: {'name': 'Melvin Frank', 'DOB': '1913-08-13', 'Birth Country': 'U.S.', 'DOD': '1988-10-13'}
# Fetched: https://en.wikipedia.org/wiki/American_Graffiti
# Movie: {'Name': 'American Graffiti', 'Release date': '1973-08-02', 'Distributed by': 'Universal Pictures', 'Language': 'English', 'Running time': '112'}
# Fetched: https://en.wikipedia.org/wiki/Cries_and_Whispers
# Movie: {'Name': 'Cries and Whispers', 'Release date': '1972-12-21', 'Distributed by': 'N/A', 'Language': 'Swedish', 'Running time': '91'}
# Fetched: https://en.wikipedia.org/wiki/The_Exorcist
# Movie: {'Name': 'The Exorcist', 'Release date': '1973-12-26', 'Distributed by': 'Warner Bros. (United States)', 'Language': 'N/A', 'Running time': '122'}
# Fetched: https://en.wikipedia.org/wiki/A_Touch_of_Class_(film)
# Movie: {'Name': 'A Touch of Class', 'Release date': '1973-06-20', 'Distributed by': 'AVCO Embassy Pictures', 'Language': 'N/A', 'Running time': '106'}
# Fetched: https://en.wikipedia.org/wiki/George_Roy_Hill
# Actor: {'name': 'George Roy Hill', 'DOB': '1921-12-20', 'Birth Country': 'U.S.', 'DOD': '2002-12-27'}
# Fetched: https://en.wikipedia.org/wiki/George_Lucas
# Actor: {'name': 'George Lucas', 'DOB': '1944-05-14', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping Ingmar Bergman- https://en.wikipedia.org/wiki/Ingmar_Bergman (already visited)
# Fetched: https://en.wikipedia.org/wiki/William_Friedkin
# Actor: {'name': 'William Friedkin', 'DOB': '1935-08-29', 'Birth Country': 'U.S.', 'DOD': '2023-08-07'}
# Fetched: https://en.wikipedia.org/wiki/Bernardo_Bertolucci
# Actor: {'name': 'Bernardo Bertolucci', 'DOB': '1941-03-16', 'Birth Country': 'Italy', 'DOD': '2018-11-26'}
# Skipping American Graffiti- https://en.wikipedia.org/wiki/American_Graffiti (already visited)
# Skipping Cries and Whispers- https://en.wikipedia.org/wiki/Cries_and_Whispers (already visited)
# Skipping The Exorcist- https://en.wikipedia.org/wiki/The_Exorcist (already visited)
# Fetched: https://en.wikipedia.org/wiki/Last_Tango_in_Paris
# Movie: {'Name': 'Last Tango in Paris', 'Release date': '1972-10-14', 'Distributed by': 'United Artists', 'Language': 'N/A', 'Running time': '129'}
# Fetched: https://en.wikipedia.org/wiki/Jack_Lemmon
# Actor: {'name': 'Jack Lemmon', 'DOB': '1925-02-08', 'Birth Country': 'U.S.', 'DOD': '2001-06-27'}
# Skipping Marlon Brando- https://en.wikipedia.org/wiki/Marlon_Brando (already visited)
# Fetched: https://en.wikipedia.org/wiki/Jack_Nicholson
# Actor: {'name': 'Jack Nicholson', 'DOB': '1937-04-22', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping Al Pacino- https://en.wikipedia.org/wiki/Al_Pacino (already visited)
# Fetched: https://en.wikipedia.org/wiki/Frank_Serpico
# Actor: {'name': 'Frank Serpico', 'DOB': '1936-04-14', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Robert_Redford
# Actor: {'name': 'Robert Redford', 'DOB': '1936-08-18', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping Last Tango in Paris- https://en.wikipedia.org/wiki/Last_Tango_in_Paris (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Last_Detail
# Movie: {'Name': 'The Last Detail', 'Release date': '1973-12-12', 'Distributed by': 'Columbia Pictures', 'Language': 'English', 'Running time': '104'}
# Fetched: https://en.wikipedia.org/wiki/Serpico
# Movie: {'Name': 'Serpico', 'Release date': '1974-02-06', 'Distributed by': 'Paramount Pictures', 'Language': 'English', 'Running time': '130'}
# Fetched: https://en.wikipedia.org/wiki/The_Sting
# Movie: {'Name': 'The Sting', 'Release date': '1973-12-25', 'Distributed by': 'Universal Pictures', 'Language': 'English', 'Running time': '129'}
# Fetched: https://en.wikipedia.org/wiki/Glenda_Jackson
# Actor: {'name': 'Glenda Jackson', 'DOB': '1936-05-09', 'Birth Country': 'England', 'DOD': '2023-06-15'}
# Fetched: https://en.wikipedia.org/wiki/Ellen_Burstyn
# Actor: {'name': 'Ellen Burstyn', 'DOB': '1932-12-07', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Marsha_Mason
# Actor: {'name': 'Marsha Mason', 'DOB': '1942-04-03', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Barbra_Streisand
# Actor: {'name': 'Barbra Streisand', 'DOB': '1942-04-24', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Joanne_Woodward
# Actor: {'name': 'Joanne Woodward', 'DOB': '1930-02-27', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping The Exorcist- https://en.wikipedia.org/wiki/The_Exorcist (already visited)
# Fetched: https://en.wikipedia.org/wiki/Cinderella_Liberty
# Movie: {'Name': 'Cinderella Liberty', 'Release date': '1973-12-18', 'Distributed by': '20th Century Fox', 'Language': 'English', 'Running time': '117'}
# Fetched: https://en.wikipedia.org/wiki/The_Way_We_Were
# Movie: {'Name': 'The Way We Were', 'Release date': '1973-10-19', 'Distributed by': 'Columbia Pictures', 'Language': 'English', 'Running time': '118'}
# Fetched: https://en.wikipedia.org/wiki/Summer_Wishes,_Winter_Dreams
# Movie: {'Name': 'Summer Wishes, Winter Dreams', 'Release date': '1973-10-21', 'Distributed by': 'Columbia Pictures', 'Language': 'English', 'Running time': '93'}
# Fetched: https://en.wikipedia.org/wiki/John_Houseman
# Actor: {'name': 'John Houseman', 'DOB': '1902-09-22', 'Birth Country': 'Kingdom of Romania', 'DOD': '1988-10-31'}
# Fetched: https://en.wikipedia.org/wiki/Vincent_Gardenia
# Actor: {'name': 'Vincent Gardenia', 'DOB': '1920-01-07', 'Birth Country': 'Italy', 'DOD': '1992-12-09'}
# Fetched: https://en.wikipedia.org/wiki/Jack_Gilford
# Actor: {'name': 'Jack Gilford', 'DOB': '1908-07-25', 'Birth Country': 'U.S.', 'DOD': '1990-06-04'}
# Fetched: https://en.wikipedia.org/wiki/Jason_Miller_(playwright)
# Actor: {'name': 'Jason Miller', 'DOB': '1939-04-22', 'Birth Country': 'U.S.', 'DOD': '2001-05-13'}
# Fetched: https://en.wikipedia.org/wiki/Damien_Karras
# Actor: {'name': 'Damien Karras', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Randy_Quaid
# Actor: {'name': 'Randy Quaid', 'DOB': '1950-10-01', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Bang_the_Drum_Slowly_(film)
# Movie: {'Name': 'Bang the Drum Slowly', 'Release date': '1973-08-26', 'Distributed by': 'Paramount Pictures', 'Language': 'English', 'Running time': '96'}
# Fetched: https://en.wikipedia.org/wiki/Save_the_Tiger
# Movie: {'Name': 'Save the Tiger', 'Release date': '1973-02-14', 'Distributed by': 'Paramount Pictures Corporation', 'Language': 'English', 'Running time': '100'}
# Skipping The Exorcist- https://en.wikipedia.org/wiki/The_Exorcist (already visited)
# Skipping The Last Detail- https://en.wikipedia.org/wiki/The_Last_Detail (already visited)
# Fetched: https://en.wikipedia.org/wiki/Tatum_O%27Neal
# Actor: {'name': "Tatum O'Neal", 'DOB': '1963-11-05', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Linda_Blair
# Actor: {'name': 'Linda Blair', 'DOB': '1959-01-22', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Regan_MacNeil
# Actor: {'name': 'Regan MacNeil', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Candy_Clark
# Actor: {'name': 'Candy Clark', 'DOB': '1947-06-20', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Madeline_Kahn
# Actor: {'name': 'Madeline Kahn', 'DOB': '1942-09-29', 'Birth Country': 'U.S.', 'DOD': '1999-12-03'}
# Fetched: https://en.wikipedia.org/wiki/Sylvia_Sidney
# Actor: {'name': 'Sylvia Sidney', 'DOB': '1910-08-08', 'Birth Country': 'U.S.', 'DOD': '1999-07-01'}
# Skipping The Exorcist- https://en.wikipedia.org/wiki/The_Exorcist (already visited)
# Skipping American Graffiti- https://en.wikipedia.org/wiki/American_Graffiti (already visited)
# Fetched: https://en.wikipedia.org/wiki/Paper_Moon_(film)
# Movie: {'Name': 'Paper Moon', 'Release date': '1973-04-09', 'Distributed by': 'Paramount Pictures', 'Language': 'English', 'Running time': '102'}
# Skipping Summer Wishes, Winter Dreams- https://en.wikipedia.org/wiki/Summer_Wishes,_Winter_Dreams (already visited)
# Fetched: https://en.wikipedia.org/wiki/David_S._Ward
# Actor: {'name': 'David S. Ward', 'DOB': '1945-10-25', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping George Lucas- https://en.wikipedia.org/wiki/George_Lucas (already visited)
# Fetched: https://en.wikipedia.org/wiki/Gloria_Katz
# Actor: {'name': 'Gloria Katz', 'DOB': '1942-10-25', 'Birth Country': 'U.S.', 'DOD': '2018-11-25'}
# Fetched: https://en.wikipedia.org/wiki/Willard_Huyck
# Actor: {'name': 'Willard Huyck', 'DOB': '1945-09-08', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Skipping Ingmar Bergman- https://en.wikipedia.org/wiki/Ingmar_Bergman (already visited)
# Fetched: https://en.wikipedia.org/wiki/Steve_Shagan
# Actor: {'name': 'Steve Shagan', 'DOB': '1927-10-25', 'Birth Country': 'U.S.', 'DOD': '2015-11-30'}
# Skipping Melvin Frank- https://en.wikipedia.org/wiki/Melvin_Frank (already visited)
# Fetched: https://en.wikipedia.org/wiki/Jack_Rose_(screenwriter)
# Actor: {'name': 'Jack Rose', 'DOB': '1911-11-04', 'Birth Country': 'Russian Empire', 'DOD': '1995-10-20'}
# Skipping American Graffiti- https://en.wikipedia.org/wiki/American_Graffiti (already visited)
# Skipping Cries and Whispers- https://en.wikipedia.org/wiki/Cries_and_Whispers (already visited)
# Skipping Save the Tiger- https://en.wikipedia.org/wiki/Save_the_Tiger (already visited)
# Skipping A Touch of Class- https://en.wikipedia.org/wiki/A_Touch_of_Class_(film) (already visited)
# Skipping William Peter Blatty- https://en.wikipedia.org/wiki/William_Peter_Blatty (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Exorcist_(novel)
# Actor: {'name': 'his novel', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Robert_Towne
# Actor: {'name': 'Robert Towne', 'DOB': '1934-11-23', 'Birth Country': 'U.S.', 'DOD': '2024-07-01'}
# Fetched: https://en.wikipedia.org/wiki/Darryl_Ponicsan
# Actor: {'name': 'Darryl Ponicsan', 'DOB': '1938-05-26', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/James_Bridges
# Actor: {'name': 'James Bridges', 'DOB': '1936-02-03', 'Birth Country': 'Arkansas', 'DOD': '1993-06-06'}
# Fetched: https://en.wikipedia.org/wiki/The_Paper_Chase_(Osborn_novel)
# infobox not found for the novel - https://en.wikipedia.org/wiki/The_Paper_Chase_(Osborn_novel)
# Fetched: https://en.wikipedia.org/wiki/John_Jay_Osborn_Jr.
# Actor: {'name': 'John Jay Osborn Jr.', 'DOB': '1945-08-05', 'Birth Country': 'U.S.', 'DOD': '2022-10-19'}
# Fetched: https://en.wikipedia.org/wiki/Alvin_Sargent
# Actor: {'name': 'Alvin Sargent', 'DOB': '1927-04-12', 'Birth Country': 'U.S.', 'DOD': '2019-05-09'}
# Fetched: https://en.wikipedia.org/wiki/Joe_David_Brown
# infobox not found for Joe David Brown - https://en.wikipedia.org/wiki/Joe_David_Brown
# Fetched: https://en.wikipedia.org/wiki/Waldo_Salt
# Actor: {'name': 'Waldo Salt', 'DOB': '1914-10-18', 'Birth Country': 'U.S.', 'DOD': '1987-03-07'}
# Fetched: https://en.wikipedia.org/wiki/Norman_Wexler
# Actor: {'name': 'Norman Wexler', 'DOB': '1926-08-16', 'Birth Country': 'U.S.', 'DOD': '1999-08-23'}
# Fetched: https://en.wikipedia.org/wiki/Peter_Maas
# Actor: {'name': 'Peter Maas', 'DOB': '1929-06-27', 'Birth Country': 'U.S.', 'DOD': '2001-08-23'}
# ...
# Fetched: https://en.wikipedia.org/wiki/Blackwood_(1976_film)
# Movie: {'Name': 'Blackwood', 'Release date': '1976 ( 1976 )', 'Distributed by': 'National Film Board of Canada', 'Language': 'N/A', 'Running time': '28'}
# Fetched: https://en.wikipedia.org/wiki/The_End_of_the_Road_(1976_film)
# Movie: {'Name': 'The End of the Road', 'Release date': '1976 ( 1976 )', 'Distributed by': 'BP', 'Language': 'English', 'Running time': '23'}
# Fetched: https://en.wikipedia.org/wiki/Universe_(1976_film)
# Movie: {'Name': 'Universe', 'Release date': '1976 ( 1976 )', 'Distributed by': 'National Aeronautics and Space Administration', 'Language': 'English', 'Running time': '27'}
# Fetched: https://en.wikipedia.org/wiki/Andre_R._Guttfreund
# Actor: {'name': 'Andre R. Guttfreund', 'DOB': '1946-11-06', 'Birth Country': '1946 El Salvador', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Peter_Werner
# Actor: {'name': 'Peter Werner', 'DOB': '1947-01-17', 'Birth Country': 'U.S.', 'DOD': '2023-03-21'}
# Skipping Claire Wilbur- https://en.wikipedia.org/wiki/Claire_Wilbur (already visited)
# Skipping Robin Lehman- https://en.wikipedia.org/wiki/Robin_Lehman (already visited)
# Fetched: https://en.wikipedia.org/wiki/Dyan_Cannon
# Actor: {'name': 'Dyan Cannon', 'DOB': '1937-01-04', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Suzanne_Baker
# Actor: {'name': 'Suzanne Baker', 'DOB': '1939 (age\xa085–86) England', 'Birth Country': '1939 (age\xa085–86) England', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Caroline_Leaf
# Actor: {'name': 'Caroline Leaf', 'DOB': '1946-08-12', 'Birth Country': 'United States', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/The_Street_(1976_film)
# Movie: {'Name': 'The Street', 'Release date': 'N/A', 'Distributed by': 'National Film Board of Canada', 'Language': 'English', 'Running time': '10'}
# Skipping Jerry Goldsmith- https://en.wikipedia.org/wiki/Jerry_Goldsmith (already visited)
# Fetched: https://en.wikipedia.org/wiki/Bernard_Herrmann
# Actor: {'name': 'Bernard Herrmann', 'DOB': '1911-06-29', 'Birth Country': 'U.S.', 'DOD': '1975-12-24'}
# Fetched: https://en.wikipedia.org/wiki/Jerry_Fielding
# Actor: {'name': 'Jerry Fielding', 'DOB': '1922-06-17', 'Birth Country': 'U.S.', 'DOD': '1980-02-17'}
# Skipping Bernard Herrmann- https://en.wikipedia.org/wiki/Bernard_Herrmann (already visited)
# Fetched: https://en.wikipedia.org/wiki/Lalo_Schifrin
# Actor: {'name': 'Lalo Schifrin', 'DOB': '1932-06-21', 'Birth Country': 'Argentina', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Obsession_(1976_film)
# Movie: {'Name': 'Obsession', 'Release date': '1976-08-01', 'Distributed by': 'Columbia Pictures', 'Language': 'English', 'Running time': '98'}
# Fetched: https://en.wikipedia.org/wiki/The_Outlaw_Josey_Wales
# Movie: {'Name': 'The Outlaw Josey Wales', 'Release date': '1976-06-30', 'Distributed by': 'Warner Bros.', 'Language': 'English', 'Running time': '135'}
# Skipping Taxi Driver- https://en.wikipedia.org/wiki/Taxi_Driver (already visited)
# Skipping Voyage of the Damned- https://en.wikipedia.org/wiki/Voyage_of_the_Damned (already visited)
# Skipping Leonard Rosenman- https://en.wikipedia.org/wiki/Leonard_Rosenman (already visited)
# Skipping Paul Williams- https://en.wikipedia.org/wiki/Paul_Williams_(songwriter) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Roger_Kellaway
# infobox not found for Roger Kellaway - https://en.wikipedia.org/wiki/Roger_Kellaway
# Fetched: https://en.wikipedia.org/wiki/Bugsy_Malone
# Movie: {'Name': 'Bugsy Malone', 'Release date': '1976-07-23', 'Distributed by': 'Fox - Rank Distributors (United Kingdom) Paramount Pictures (United States)', 'Language': 'N/A', 'Running time': '93'}
# Fetched: https://en.wikipedia.org/wiki/A_Star_Is_Born_(1976_film)
# Movie: {'Name': 'A Star Is Born', 'Release date': '1976-12-18', 'Distributed by': 'Warner Bros.', 'Language': 'English', 'Running time': '142'}
# Fetched: https://en.wikipedia.org/wiki/Evergreen_(Love_Theme_from_A_Star_Is_Born)
# Actor: {'name': 'Evergreen (Love Theme from A Star Is Born)', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Skipping Barbra Streisand- https://en.wikipedia.org/wiki/Barbra_Streisand (already visited)
# Skipping Paul Williams- https://en.wikipedia.org/wiki/Paul_Williams_(songwriter) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Ave_Satani
# Actor: {'name': 'Ave Satani', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Skipping Jerry Goldsmith- https://en.wikipedia.org/wiki/Jerry_Goldsmith (already visited)
# Fetched: https://en.wikipedia.org/wiki/Henry_Mancini
# Actor: {'name': 'Henry Mancini', 'DOB': '1924-04-16', 'Birth Country': 'U.S.', 'DOD': '1994-06-14'}
# Skipping Don Black- https://en.wikipedia.org/wiki/Don_Black_(lyricist) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Gonna_Fly_Now
# Actor: {'name': 'Gonna Fly Now', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Bill_Conti
# Actor: {'name': 'Bill Conti', 'DOB': '1942-04-13', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Carol_Connors_(singer)
# Actor: {'name': 'Carol Connors', 'DOB': '1941-11-13', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Ayn_Robbins
# infobox not found for Ayn Robbins - https://en.wikipedia.org/wiki/Ayn_Robbins
# Skipping Sammy Fain- https://en.wikipedia.org/wiki/Sammy_Fain (already visited)
# Skipping Paul Francis Webster- https://en.wikipedia.org/wiki/Paul_Francis_Webster (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Omen
# Movie: {'Name': 'The Omen', 'Release date': '1976-06-06', 'Distributed by': 'Fox-Rank Distributors (United Kingdom) 20th Century-Fox (United States)', 'Language': 'English', 'Running time': '111'}
# Fetched: https://en.wikipedia.org/wiki/The_Pink_Panther_Strikes_Again
# Movie: {'Name': 'The Pink Panther Strikes Again', 'Release date': '1976-12-15', 'Distributed by': 'United Artists', 'Language': 'English', 'Running time': '103'}
# Skipping Rocky- https://en.wikipedia.org/wiki/Rocky (already visited)
# Fetched: https://en.wikipedia.org/wiki/Half_a_House
# Movie: {'Name': 'Half a House', 'Release date': '1976-12-17', 'Distributed by': 'Rampart Releasing', 'Language': 'English', 'Running time': '95'}
# Skipping Arthur Piantadosi- https://en.wikipedia.org/wiki/Arthur_Piantadosi (already visited)
# Skipping Les Fresholtz- https://en.wikipedia.org/wiki/Les_Fresholtz (already visited)
# Fetched: https://en.wikipedia.org/wiki/Dick_Alexander
# Actor: {'name': 'Dick Alexander', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Jim_Webb_(audio_engineer)
# Actor: {'name': 'Jim Webb', 'DOB': 'N/A', 'Birth Country': 'James E. Webb', 'DOD': 'N/A'}
# Skipping Harry Warren Tetrick- https://en.wikipedia.org/wiki/Harry_W._Tetrick (already visited)
# Skipping William McCaughey- https://en.wikipedia.org/wiki/William_McCaughey (already visited)
# Skipping Aaron Rochin- https://en.wikipedia.org/wiki/Aaron_Rochin (already visited)
# Skipping Jack Solomon- https://en.wikipedia.org/wiki/Jack_Solomon_(sound_engineer) (already visited)
# Skipping Harry Warren Tetrick- https://en.wikipedia.org/wiki/Harry_W._Tetrick (already visited)
# Skipping William McCaughey- https://en.wikipedia.org/wiki/William_McCaughey (already visited)
# Fetched: https://en.wikipedia.org/wiki/Lyle_J._Burbridge
# Actor: {'name': 'Lyle Burbridge', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': '2006-01-16'}
# Fetched: https://en.wikipedia.org/wiki/Bud_Alper
# Actor: {'name': 'Bud Alper', 'DOB': '1930-08-24', 'Birth Country': '1930', 'DOD': '2012-12-19'}
# Skipping Donald Mitchell- https://en.wikipedia.org/wiki/Donald_O._Mitchell (already visited)
# Fetched: https://en.wikipedia.org/wiki/Douglas_Williams_(sound_engineer)
# Actor: {'name': 'Douglas Williams', 'DOB': '1917-07-29', 'Birth Country': '1917', 'DOD': '1993-01-31'}
# Skipping Richard Tyler- https://en.wikipedia.org/wiki/Richard_Tyler_(sound_engineer) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Harold_M._Etherington
# Actor: {'name': 'Hal Etherington', 'DOB': 'N/A', 'Birth Country': 'N/A', 'DOD': 'N/A'}
# Skipping Robert Knudson- https://en.wikipedia.org/wiki/Robert_Knudson (already visited)
# Fetched: https://en.wikipedia.org/wiki/Dan_Wallin
# Actor: {'name': 'Dan Wallin', 'DOB': '1927-03-13', 'Birth Country': 'U.S.', 'DOD': '2024-04-10'}
# Fetched: https://en.wikipedia.org/wiki/Robert_Glass_(sound_engineer)
# Actor: {'name': 'Robert Glass', 'DOB': '1939-12-04', 'Birth Country': 'USA', 'DOD': '1993-07-21'}
# Fetched: https://en.wikipedia.org/wiki/Tom_Overton
# Actor: {'name': 'Tom Overton', 'DOB': '1930-04-14', 'Birth Country': 'USA', 'DOD': '1988-05-04'}
# Fetched: https://en.wikipedia.org/wiki/King_Kong_(1976_film)
# Movie: {'Name': 'King Kong', 'Release date': '1976-12-17', 'Distributed by': 'Paramount Pictures', 'Language': 'English', 'Running time': '134'}
# Skipping Rocky- https://en.wikipedia.org/wiki/Rocky (already visited)
# Fetched: https://en.wikipedia.org/wiki/Silver_Streak_(film)
# Movie: {'Name': 'Silver Streak', 'Release date': '1976-12-08', 'Distributed by': '20th Century Fox', 'Language': 'English', 'Running time': '114'}
# Skipping A Star Is Born- https://en.wikipedia.org/wiki/A_Star_Is_Born_(1976_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Danilo_Donati
# Actor: {'name': 'Danilo Donati', 'DOB': '1926-04-06', 'Birth Country': 'Kingdom of Italy', 'DOD': '2001-12-01'}
# Fetched: https://en.wikipedia.org/wiki/William_Ware_Theiss
# Actor: {'name': 'William Ware Theiss', 'DOB': '1931-11-20', 'Birth Country': 'US', 'DOD': '1992-12-15'}
# Skipping Anthony Mendleson- https://en.wikipedia.org/wiki/Anthony_Mendleson (already visited)
# Fetched: https://en.wikipedia.org/wiki/Mary_Wills_(costume_designer)
# infobox not found for Mary Wills - https://en.wikipedia.org/wiki/Mary_Wills_(costume_designer)
# Fetched: https://en.wikipedia.org/wiki/Alan_Barrett_(costume_designer)
# Actor: {'name': 'Alan Barrett', 'DOB': '17 March 1938 Wolverhampton', 'Birth Country': '17 March 1938 Wolverhampton', 'DOD': '1991-08-26'}
# Skipping Bound for Glory- https://en.wikipedia.org/wiki/Bound_for_Glory_(1976_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Incredible_Sarah
# Movie: {'Name': 'The Incredible Sarah', 'Release date': '1976 ( 1976 )', 'Distributed by': 'Cinema International Corp. Anchor Bay Entertainment', 'Language': 'English', 'Running time': '106'}
# Fetched: https://en.wikipedia.org/wiki/The_Passover_Plot_(film)
# Movie: {'Name': 'The Passover Plot', 'Release date': '1976 ( 1976 )', 'Distributed by': 'N/A', 'Language': 'English', 'Running time': '108'}
# Skipping The Seven-Per-Cent Solution- https://en.wikipedia.org/wiki/The_Seven-Per-Cent_Solution_(film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/George_C._Jenkins
# Actor: {'name': 'George Jenkins', 'DOB': '1908-11-19', 'Birth Country': 'Maryland', 'DOD': '2007-04-06'}
# Skipping George Gaines- https://en.wikipedia.org/wiki/George_Gaines_(set_decorator) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Elliot_Scott
# Actor: {'name': 'Elliot Scott', 'DOB': '1915-07-19', 'Birth Country': 'England', 'DOD': '1993-10-29'}
# Fetched: https://en.wikipedia.org/wiki/Norman_Reynolds
# Actor: {'name': 'Norman Reynolds', 'DOB': '1934-03-26', 'Birth Country': 'England', 'DOD': '2023-04-02'}
# Fetched: https://en.wikipedia.org/wiki/Peter_Howitt_(set_decorator)
# Actor: {'name': 'Peter Howitt', 'DOB': '1928 ( 1928 ) London, England', 'Birth Country': 'England', 'DOD': '22 September 2021 (aged 93) Malta'}
# Fetched: https://en.wikipedia.org/wiki/Gene_Callahan
# infobox not found for Gene Callahan - https://en.wikipedia.org/wiki/Gene_Callahan
# Fetched: https://en.wikipedia.org/wiki/Jack_T._Collis
# Actor: {'name': 'Jack T. Collis', 'DOB': '1923-01-12', 'Birth Country': 'California', 'DOD': '1998-02-01'}
# Skipping Jerry Wunderlich- https://en.wikipedia.org/wiki/Jerry_Wunderlich (already visited)
# Fetched: https://en.wikipedia.org/wiki/Dale_Hennesy
# Actor: {'name': 'Dale Hennesy', 'DOB': '1926-08-24', 'Birth Country': 'D.C. [ 1 ]', 'DOD': '1981-07-20'}
# Skipping Robert De Vestel- https://en.wikipedia.org/wiki/Robert_De_Vestel (already visited)
# Fetched: https://en.wikipedia.org/wiki/Robert_F._Boyle
# Actor: {'name': 'Robert F. Boyle', 'DOB': '1909-10-10', 'Birth Country': 'U.S.', 'DOD': '2010-08-01'}
# Fetched: https://en.wikipedia.org/wiki/Arthur_Jeph_Parker
# Actor: {'name': 'Arthur Jeph Parker', 'DOB': '1923-06-04', 'Birth Country': '1923', 'DOD': '2002-12-15'}
# Skipping The Incredible Sarah- https://en.wikipedia.org/wiki/The_Incredible_Sarah (already visited)
# Fetched: https://en.wikipedia.org/wiki/The_Last_Tycoon_(1976_film)
# Movie: {'Name': 'The Last Tycoon', 'Release date': '1976-11-17', 'Distributed by': 'Paramount Pictures', 'Language': 'English', 'Running time': '123'}
# Fetched: https://en.wikipedia.org/wiki/Logan%27s_Run_(film)
# Movie: {'Name': "Logan's Run", 'Release date': '1976-06-23', 'Distributed by': 'United Artists', 'Language': 'English', 'Running time': '118'}
# Fetched: https://en.wikipedia.org/wiki/The_Shootist
# Movie: {'Name': 'The Shootist', 'Release date': '1976-07-21', 'Distributed by': 'Paramount Pictures (USA/UK)', 'Language': 'English', 'Running time': '100'}
# Skipping Haskell Wexler- https://en.wikipedia.org/wiki/Haskell_Wexler (already visited)
# Fetched: https://en.wikipedia.org/wiki/Richard_H._Kline
# Actor: {'name': 'Richard H. Kline', 'DOB': '1926-11-15', 'Birth Country': 'U.S.', 'DOD': '2018-08-07'}
# Fetched: https://en.wikipedia.org/wiki/Ernest_Laszlo
# Actor: {'name': 'Ernest Laszlo', 'DOB': '1898-04-23', 'Birth Country': 'Austria-Hungary', 'DOD': '1984-01-06'}
# Skipping Owen Roizman- https://en.wikipedia.org/wiki/Owen_Roizman (already visited)
# Skipping Robert Surtees- https://en.wikipedia.org/wiki/Robert_Surtees_(cinematographer) (already visited)
# Skipping King Kong- https://en.wikipedia.org/wiki/King_Kong_(1976_film) (already visited)
# Skipping Logan's Run- https://en.wikipedia.org/wiki/Logan%27s_Run_(film) (already visited)
# Skipping Network- https://en.wikipedia.org/wiki/Network_(1976_film) (already visited)
# Skipping A Star Is Born- https://en.wikipedia.org/wiki/A_Star_Is_Born_(1976_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Richard_Halsey
# Actor: {'name': 'Richard Halsey', 'DOB': '1940 (age\xa084–85)', 'Birth Country': '1940 (age\xa084–85)', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Scott_Conrad
# Actor: {'name': 'Scott Conrad', 'DOB': '1944 (age\xa080–81)', 'Birth Country': '1944 (age\xa080–81)', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Robert_L._Wolfe
# Actor: {'name': 'Robert L. Wolfe', 'DOB': '1928-07-05', 'Birth Country': '1928', 'DOD': '1981-02-28'}
# Fetched: https://en.wikipedia.org/wiki/Robert_C._Jones
# Actor: {'name': 'Robert C. Jones', 'DOB': '1936-03-30', 'Birth Country': 'U.S.', 'DOD': '2021-02-01'}
# Fetched: https://en.wikipedia.org/wiki/Pembroke_J._Herring
# Actor: {'name': 'Pembroke J. Herring', 'DOB': '1930-04-15', 'Birth Country': '1930', 'DOD': '2020-05-19'}
# Fetched: https://en.wikipedia.org/wiki/Alan_Heim
# Actor: {'name': 'Alan Heim', 'DOB': '1936-05-21', 'Birth Country': 'U.S.', 'DOD': 'N/A'}
# Fetched: https://en.wikipedia.org/wiki/Eve_Newman
# Actor: {'name': 'Eve Newman', 'DOB': '1915-07-24', 'Birth Country': 'U.S.', 'DOD': '2003-10-10'}
# Fetched: https://en.wikipedia.org/wiki/Walter_Hannemann
# Actor: {'name': 'Walter Hannemann', 'DOB': '1912-05-02', 'Birth Country': 'U.S.', 'DOD': '2001-04-29'}
# Skipping All the President's Men- https://en.wikipedia.org/wiki/All_the_President%27s_Men_(film) (already visited)
# Skipping Bound for Glory- https://en.wikipedia.org/wiki/Bound_for_Glory_(1976_film) (already visited)
# Skipping Network- https://en.wikipedia.org/wiki/Network_(1976_film) (already visited)
# Fetched: https://en.wikipedia.org/wiki/Two-Minute_Warning
# Movie: {'Name': 'Two-Minute Warning', 'Release date': '1976-11-12', 'Distributed by': 'Universal Pictures', 'Language': 'English', 'Running time': '115'}

# %% [markdown]
# Create the panda Dataframe for movies.
#
# Remove problematic datapoints.

# %%
import pandas as pd

actors_df = pd.DataFrame(actors)
names_to_remove = ["his play","the book","his novel","his book", "the novel", "the play","Belgium","Israel","20th Century Fox","United Kingdom"]

# Filter the DataFrame to exclude these names
actors_df = actors_df[~actors_df['name'].isin(names_to_remove)]
actors_df.rename(columns={
    'name': 'Name',

}, inplace=True)


actors_df.to_csv('actors.csv', index=False)
print("Actors DataFrame:")
print(actors_df)
# Out:
# Actors DataFrame:
#                             Name         DOB Birth Country         DOD
# 0                   Henry Blanke  1901-12-30       Germany  1981-05-28
# 1                   Warner Bros.         N/A           N/A         N/A
# 2                    Leo McCarey  1898-10-03          U.S.  1969-07-05
# 3                       Columbia         N/A           N/A         N/A
# 4               Louis D. Lighton  1895-11-25           USA  1963-02-01
# ...                          ...         ...           ...         ...
# 6906                 Theo Bialek         N/A           N/A         N/A
# 6907                 Alex Wuttke         N/A           N/A         N/A
# 6908                 Simone Coco         N/A           N/A         N/A
# 6909             Jeff Sutherland         N/A           N/A         N/A
# 6910  Luc-Ewen Martin-Fenouillet         N/A           N/A         N/A
#
# [6762 rows x 4 columns]

# %% [markdown]
# Create the movies Dataframe
#
# and update the names

# %%
movies_df = pd.DataFrame(movies)
# Rename columns in the movies DataFrame
movies_df.rename(columns={
    'Name': 'Title',
    'Release date': 'releaseDate',
    'Running time': 'runTime',
    'Distributed by': 'productionCompany'
}, inplace=True)


print(movies_df)

# save the updated DataFrame to a csv
movies_df.to_csv('movies.csv', index=False)
# Out:
#                                               Title releaseDate  \
# 0                            The Life of Emile Zola  1937-08-11
# 1                                   The Awful Truth  1937-10-21
# 2                               Captains Courageous  1937-05-11
# 3                                          Dead End  1937-08-27
# 4                                    The Good Earth  1937-01-29
# ...                                             ...         ...
# 4112  Mission: Impossible – Dead Reckoning Part One  2023-06-19
# 4113                                       Napoleon  2023-11-14
# 4114                                       El Conde  2023-08-31
# 4115                                          Golda  2023-02-20
# 4116                 Guardians of the Galaxy Vol. 3  2023-04-22
#
#                                       productionCompany Language runTime
# 0                                 Warner Bros. Pictures  English     116
# 1                                     Columbia Pictures  English      91
# 2                                           Loew's Inc.  English     117
# 3                                        United Artists  English      93
# 4                                          Loew's, Inc.  English     138
# ...                                                 ...      ...     ...
# 4112                                 Paramount Pictures  English     163
# 4113                                  Columbia Pictures  English     157
# 4114                                            Netflix      N/A     110
# 4115  Bleecker Street ShivHans Pictures (United States)  English     100
# 4116                Walt Disney Studios Motion Pictures  English     150
#
# [4117 rows x 5 columns]

# %% [markdown]
#  See the duplicate Movies

# %%
duplicate_movies = movies_df[movies_df.duplicated(subset=['Title', 'releaseDate'], keep=False)]

# Display the duplicate movies
print("Movies with the same name and release date:")
print(duplicate_movies)
# Out:
# Movies with the same name and release date:
#                   Title releaseDate productionCompany Language runTime
# 1031  Blackboard Jungle  1955-03-20       Loew's Inc.  English     101
# 1032  Blackboard Jungle  1955-03-20       Loew's Inc.  English     101

# %% [markdown]
# Remove the duplicates and update the CSV

# %%
# Remove duplicates based on 'Name' and 'Release date', keeping the first occurrence
movies_no_duplicates = movies_df.drop_duplicates(subset=['Title', 'releaseDate'], keep='first')

# Save the result to a CSV file
movies_no_duplicates.to_csv('movies.csv', index=False)

print("Movies without duplicates saved to: movies.csv")
# Out:
# Movies without duplicates saved to: movies.csv

# %% [markdown]
# See the duplicate Actors

# %%
duplicate_actors = actors_df[actors_df.duplicated(subset=['Name', 'DOB'], keep=False)]

# Display the duplicates
print("Duplicate actors based on name and DOB:")
print(duplicate_actors)
# Out:
# Duplicate actors based on name and DOB:
#                         Name         DOB  Birth Country         DOD
# 16                 RKO Radio         N/A            N/A         N/A
# 64                 RKO Radio         N/A            N/A         N/A
# 94           Elmer A. Raguse  1901-05-09  United States  1972-03-02
# 178            Alfred Newman  1900-03-17           U.S.  1970-02-17
# 192               Bob Wright  1914-09-25           U.S.  2005-07-27
# ...                      ...         ...            ...         ...
# 6502  Bosnia and Herzegovina         N/A            N/A         N/A
# 6615         the short story         N/A            N/A         N/A
# 6680           Tristan Myles         N/A            N/A         N/A
# 6754            Hold My Hand         N/A            N/A         N/A
# 6877           Gary A. Rizzo  1972-01-31  United States         N/A
#
# [116 rows x 4 columns]

# %% [markdown]
# Remove duplicates and update CSV

# %%
actors_no_duplicates = actors_df.drop_duplicates(subset=['Name', 'DOB'], keep='first')

# Optionally, save the updated DataFrame to a new CSV
actors_no_duplicates.to_csv('actors.csv', index=False)

# %% [markdown]
# create nominations_df
# and The awards Csv

# %%
nominations_df = awards_df
awards_df = awards_df.iloc[:, :2]  # Select the first two columns

# Save to CSV without modifying the original DataFrame
awards_df.to_csv("awards.csv", index=False)

# %% [markdown]
# Create the nominations.csv

# %%
nominations_df.to_csv ("nominations.csv", index=False)

# %% [markdown]
# See the unique categories

# %%
unique_categories = awards_df['Category'].unique()
print(unique_categories)
# Out:
# ['Outstanding Production' 'Best Directing' 'Best Actor' 'Best Actress'
#  'Best Actor in a Supporting Role' 'Best Actress in a Supporting Role'
#  'Best Writing (Original Story)' 'Best Writing (Screenplay)'
#  'Best Short Subject (One-Reel)' 'Best Short Subject (Two-Reel)'
#  'Best Short Subject (Color)' 'Best Short Subject (Cartoon)'
#  'Best Music (Scoring)' 'Best Music (Song)' 'Best Sound Recording'
#  'Best Art Direction' 'Best Cinematography' 'Best Film Editing'
#  'Best Dance Direction' 'Best Assistant Director'
#  'Best Music (Original Score)' 'Best Cinematography (Black-and-White)'
#  'Best Cinematography (Color)' 'Best Special Effects'
#  'Best Writing (Original Screenplay)'
#  'Best Art Direction (Black-and-White)' 'Best Art Direction (Color)'
#  'Outstanding Motion Picture' 'Best Documentary (Short Subject)'
#  'Best Music (Music Score of a Dramatic Picture)'
#  'Best Music (Scoring of a Musical Picture)'
#  'Best Writing (Original Motion Picture Story)' 'Best Documentary'
#  'Best Music (Music Score of a Dramatic or Comedy Picture)'
#  'Best Documentary (Feature)' 'Best Motion Picture'
#  'Best Motion Picture\n' 'Best Directing\n' 'Best Actor\n'
#  'Best Actress\n' 'Best Actor in a Supporting Role\n'
#  'Best Actress in a Supporting Role\n'
#  'Best Writing (Original Screenplay)\n' 'Best Writing (Screenplay)\n'
#  'Best Writing (Original Motion Picture Story)\n'
#  'Best Documentary (Feature)\n' 'Best Documentary (Short Subject)\n'
#  'Best Short Subject (One-Reel)\n' 'Best Short Subject (Two-Reel)\n'
#  'Best Short Subject (Cartoon)\n'
#  'Best Music (Music Score of a Dramatic or Comedy Picture)\n'
#  'Best Music (Scoring of a Musical Picture)\n' 'Best Music (Song)\n'
#  'Best Sound Recording\n' 'Best Art Direction (Black-and-White)\n'
#  'Best Art Direction (Color)\n' 'Best Cinematography (Black-and-White)\n'
#  'Best Cinematography (Color)\n' 'Best Film Editing\n'
#  'Best Special Effects\n' 'Best Writing (Motion Picture Story)\n'
#  'Best Costume Design (Black-and-White)\n' 'Best Costume Design (Color)\n'
#  'Best Writing (Story and Screenplay)\n'
#  'Best  Writing (Screenplay -- Original)\n'
#  'Best Writing (Screenplay -- Adapted)\n' 'Best Foreign Language Film\n'
#  'Best Writing (Story and Screenplay -- Written Directly for the Screen)\n'
#  'Best Writing (Screenplay -- Based on Material from Another Medium)\n'
#  'Best Short Subject (Live Action)\n' 'Best Music (Scoring)\n'
#  'Best Costume Design\n' 'Best Art Direction\n' 'Best Cinematography\n'
#  'Best Sound\n' 'Best Picture\n'
#  'Best Music (Music Score -- Substantially Original)\n'
#  'Best Music (Scoring of Music -- Adaptation or Treatment)\n'
#  'Best Sound Effects\n' 'Best Special Visual Effects\n'
#  'Best Music (Original Music Score)\n'
#  'Best Music (Original Score -- for a Motion Picture (Not a Musical))\n'
#  'Best Music (Score of a Musical Picture -- Original or Adaptation)\n'
#  'Best Song Original for the Picture\n'
#  'Best Writing (Story and Screenplay -- Based on Material Not Previously Published or Produced)\n'
#  'Best Music (Song -- Original for the Picture)\n'
#  'Best Writing (Story and Screenplay -- Based on Factual Material or Material Not Previously Published or Produced)\n'
#  'Best Music (Original Score)\n' 'Best Music (Original Song Score)\n'
#  'Best Short Subject (Animated)\n'
#  'Best Music (Original Dramatic Score)\n'
#  'Best Music (Scoring: Adaptation and Original Song Score)\n'
#  'Best Music (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)\n'
#  'Best Writing (Screenplay Adapted from Other Material)\n'
#  'Best Short Film (Live Action)\n' 'Best Short Film (Animated)\n'
#  'Best Music (Original Song)\n' 'Best Actor in a Leading Role\n'
#  'Best Actress in a Leading Role\n'
#  'Best Writing (Screenplay Written Directly for the Screen -- Based on Factual Material or on Story Material Not Previously Published or Produced)\n'
#  'Best Music (Original Song Score and Its Adaptation or Adaptation Score)\n'
#  'Best Picture' 'Best Actor in a Leading Role'
#  'Best Actress in a Leading Role'
#  'Best Writing (Screenplay Written Directly for the Screen -- Based on Factual Material or on Story Material Not Previously Published or Produced)'
#  'Best Writing (Screenplay -- Based on Material from Another Medium)[12]'
#  'Best Foreign Language Film' 'Best Short Film (Live Action)'
#  'Best Short Film (Animated)'
#  'Best Music (Original Song Score and Its Adaptation or Adaptation Score)'
#  'Best Music (Original Song)' 'Best Sound' 'Best Costume Design'
#  'Best Visual Effects'
#  'Best Writing (Screenplay Written Directly for the Screen)'
#  'Best Writing (Screenplay Based on Material from Another Medium)'
#  'Best Music (Adaptation Score)'
#  'Best Music (Original Song Score and Its Adaptation -or- Adaptation Score)'
#  'Best Short Film (Dramatic Live Action)' 'Best Makeup'
#  'Best Writing (Screenplay Written Directly for the Screen)\n'
#  'Best Writing (Screenplay Based on Material from Another Medium)\n'
#  'Best Music (Original Song Score and Its Adaptation -or- Adaptation Score)\n'
#  'Best Sound Effects Editing\n' 'Best Makeup\n' 'Best Visual Effects\n'
#  'Best Music (Original Song Score or Adaptation Score)'
#  'Best Sound Effects Editing'
#  'Best Writing (Screenplay Based on Material from Another Medium)[13]'
#  'Best Music (Original Song Score)'
#  'Best Writing (Screenplay Based on Material Previously Produced or Published)'
#  'Best Music (Original Dramatic Score)'
#  'Best Music (Original Musical or Comedy Score)' 'Best Sound Editing'
#  'Best Animated Feature Film' 'Best Writing (Adapted Screenplay)'
#  'Best Sound Mixing' 'Best Production Design'
#  'Best Makeup and Hairstyling' ' Best Directing'
#  'Best International Feature Film' 'Best Documentary Feature Film'
#  'Best Documentary Short Film' 'Best Writing (Adapted Screenplay)[22]']

# %% [markdown]
# Desgin a map to figure out the roles

# %%
from ast import keyword
category_role_mapping = {}

# Define role keywords
actor_keywords = ["Actor", "Actress", "Leading Role", "Supporting Role"]
director_keywords = ["Directing", "Assistant Director"]
writer_keywords = ["Writing", "Screenplay", "Story"]
composer_keywords = ["Music", "Song", "Score", "Scoring"]
sound_visual_keywords = ["Sound", "Visual Effects", "Sound Editing", "Sound Mixing"]
short_doc_keywords = ["Short Film", "Short Subject", "Documentary"]
design_keywords = ["Production Design", "Costume Design", "Makeup", "Art Direction"]
cinematography_editing_keywords = ["Cinematography", "Editing"]
picture_keywords = ["Picture", "Motion Picture", "Production"]
international_keywords = ["Foreign Language Film", "International Feature Film"]
vfx_keywords = ["Special Effects"]

# List of all categories (add more if needed)


def assign_role(category):
    # Check the category against each role's keywords
    if any(keyword in category for keyword in actor_keywords):
        return "Actor/Actress"
    elif any(keyword in category for keyword in director_keywords):
        return "Director"
    elif any(keyword in category for keyword in writer_keywords):
        return "Writer"
    elif any(keyword in category for keyword in composer_keywords):
        return "Composer"
    elif any(keyword in category for keyword in sound_visual_keywords):
        return "Sound/Visual Engineer"
    elif any(keyword in category for keyword in short_doc_keywords):
        return "Director/Producer"
    elif any(keyword in category for keyword in design_keywords):
        return "Designer"
    elif any(keyword in category for keyword in cinematography_editing_keywords):
        return "Cinematographer/Editor"
    elif any(keyword in category for keyword in picture_keywords):
        return "Producer"
    elif any(keyword in category for keyword in vfx_keywords):
        return "VFX artist"
    elif any(keyword in category for keyword in international_keywords):
        return "Director/Producer"
    else:
        return "Unknown"

# Map each category to a role
for category in unique_categories:
    role = assign_role(category)
    category_role_mapping[category] = role

for category, role in category_role_mapping.items():
    print(f"{category}: {role}")
# Out:
# Outstanding Production: Producer
# Best Directing: Director
# Best Actor: Actor/Actress
# Best Actress: Actor/Actress
# Best Actor in a Supporting Role: Actor/Actress
# Best Actress in a Supporting Role: Actor/Actress
# Best Writing (Original Story): Writer
# Best Writing (Screenplay): Writer
# Best Short Subject (One-Reel): Director/Producer
# Best Short Subject (Two-Reel): Director/Producer
# Best Short Subject (Color): Director/Producer
# Best Short Subject (Cartoon): Director/Producer
# Best Music (Scoring): Composer
# Best Music (Song): Composer
# Best Sound Recording: Sound/Visual Engineer
# Best Art Direction: Designer
# Best Cinematography: Cinematographer/Editor
# Best Film Editing: Cinematographer/Editor
# Best Dance Direction: Unknown
# Best Assistant Director: Director
# Best Music (Original Score): Composer
# Best Cinematography (Black-and-White): Cinematographer/Editor
# Best Cinematography (Color): Cinematographer/Editor
# Best Special Effects: VFX artist
# Best Writing (Original Screenplay): Writer
# Best Art Direction (Black-and-White): Designer
# Best Art Direction (Color): Designer
# Outstanding Motion Picture: Producer
# Best Documentary (Short Subject): Director/Producer
# Best Music (Music Score of a Dramatic Picture): Composer
# Best Music (Scoring of a Musical Picture): Composer
# Best Writing (Original Motion Picture Story): Writer
# Best Documentary: Director/Producer
# Best Music (Music Score of a Dramatic or Comedy Picture): Composer
# Best Documentary (Feature): Director/Producer
# Best Motion Picture: Producer
# Best Motion Picture
# : Producer
# Best Directing
# : Director
# Best Actor
# : Actor/Actress
# Best Actress
# : Actor/Actress
# Best Actor in a Supporting Role
# : Actor/Actress
# Best Actress in a Supporting Role
# : Actor/Actress
# Best Writing (Original Screenplay)
# : Writer
# Best Writing (Screenplay)
# : Writer
# Best Writing (Original Motion Picture Story)
# : Writer
# Best Documentary (Feature)
# : Director/Producer
# Best Documentary (Short Subject)
# : Director/Producer
# Best Short Subject (One-Reel)
# : Director/Producer
# Best Short Subject (Two-Reel)
# : Director/Producer
# Best Short Subject (Cartoon)
# : Director/Producer
# Best Music (Music Score of a Dramatic or Comedy Picture)
# : Composer
# Best Music (Scoring of a Musical Picture)
# : Composer
# Best Music (Song)
# : Composer
# Best Sound Recording
# : Sound/Visual Engineer
# Best Art Direction (Black-and-White)
# : Designer
# Best Art Direction (Color)
# : Designer
# Best Cinematography (Black-and-White)
# : Cinematographer/Editor
# Best Cinematography (Color)
# : Cinematographer/Editor
# Best Film Editing
# : Cinematographer/Editor
# Best Special Effects
# : VFX artist
# Best Writing (Motion Picture Story)
# : Writer
# Best Costume Design (Black-and-White)
# : Designer
# Best Costume Design (Color)
# : Designer
# Best Writing (Story and Screenplay)
# : Writer
# Best  Writing (Screenplay -- Original)
# : Writer
# Best Writing (Screenplay -- Adapted)
# : Writer
# Best Foreign Language Film
# : Director/Producer
# Best Writing (Story and Screenplay -- Written Directly for the Screen)
# : Writer
# Best Writing (Screenplay -- Based on Material from Another Medium)
# : Writer
# Best Short Subject (Live Action)
# : Director/Producer
# Best Music (Scoring)
# : Composer
# Best Costume Design
# : Designer
# Best Art Direction
# : Designer
# Best Cinematography
# : Cinematographer/Editor
# Best Sound
# : Sound/Visual Engineer
# Best Picture
# : Producer
# Best Music (Music Score -- Substantially Original)
# : Composer
# Best Music (Scoring of Music -- Adaptation or Treatment)
# : Composer
# Best Sound Effects
# : Sound/Visual Engineer
# Best Special Visual Effects
# : Sound/Visual Engineer
# Best Music (Original Music Score)
# : Composer
# Best Music (Original Score -- for a Motion Picture (Not a Musical))
# : Composer
# Best Music (Score of a Musical Picture -- Original or Adaptation)
# : Composer
# Best Song Original for the Picture
# : Composer
# Best Writing (Story and Screenplay -- Based on Material Not Previously Published or Produced)
# : Writer
# Best Music (Song -- Original for the Picture)
# : Composer
# Best Writing (Story and Screenplay -- Based on Factual Material or Material Not Previously Published or Produced)
# : Writer
# Best Music (Original Score)
# : Composer
# Best Music (Original Song Score)
# : Composer
# Best Short Subject (Animated)
# : Director/Producer
# Best Music (Original Dramatic Score)
# : Composer
# Best Music (Scoring: Adaptation and Original Song Score)
# : Composer
# Best Music (Scoring: Original Song Score and Adaptation -or- Scoring: Adaptation)
# : Composer
# Best Writing (Screenplay Adapted from Other Material)
# : Writer
# Best Short Film (Live Action)
# : Director/Producer
# Best Short Film (Animated)
# : Director/Producer
# Best Music (Original Song)
# : Composer
# Best Actor in a Leading Role
# : Actor/Actress
# Best Actress in a Leading Role
# : Actor/Actress
# Best Writing (Screenplay Written Directly for the Screen -- Based on Factual Material or on Story Material Not Previously Published or Produced)
# : Writer
# Best Music (Original Song Score and Its Adaptation or Adaptation Score)
# : Composer
# Best Picture: Producer
# Best Actor in a Leading Role: Actor/Actress
# Best Actress in a Leading Role: Actor/Actress
# Best Writing (Screenplay Written Directly for the Screen -- Based on Factual Material or on Story Material Not Previously Published or Produced): Writer
# Best Writing (Screenplay -- Based on Material from Another Medium)[12]: Writer
# Best Foreign Language Film: Director/Producer
# Best Short Film (Live Action): Director/Producer
# Best Short Film (Animated): Director/Producer
# Best Music (Original Song Score and Its Adaptation or Adaptation Score): Composer
# Best Music (Original Song): Composer
# Best Sound: Sound/Visual Engineer
# Best Costume Design: Designer
# Best Visual Effects: Sound/Visual Engineer
# Best Writing (Screenplay Written Directly for the Screen): Writer
# Best Writing (Screenplay Based on Material from Another Medium): Writer
# Best Music (Adaptation Score): Composer
# Best Music (Original Song Score and Its Adaptation -or- Adaptation Score): Composer
# Best Short Film (Dramatic Live Action): Director/Producer
# Best Makeup: Designer
# Best Writing (Screenplay Written Directly for the Screen)
# : Writer
# Best Writing (Screenplay Based on Material from Another Medium)
# : Writer
# Best Music (Original Song Score and Its Adaptation -or- Adaptation Score)
# : Composer
# Best Sound Effects Editing
# : Sound/Visual Engineer
# Best Makeup
# : Designer
# Best Visual Effects
# : Sound/Visual Engineer
# Best Music (Original Song Score or Adaptation Score): Composer
# Best Sound Effects Editing: Sound/Visual Engineer
# Best Writing (Screenplay Based on Material from Another Medium)[13]: Writer
# Best Music (Original Song Score): Composer
# Best Writing (Screenplay Based on Material Previously Produced or Published): Writer
# Best Music (Original Dramatic Score): Composer
# Best Music (Original Musical or Comedy Score): Composer
# Best Sound Editing: Sound/Visual Engineer
# Best Animated Feature Film: Unknown
# Best Writing (Adapted Screenplay): Writer
# Best Sound Mixing: Sound/Visual Engineer
# Best Production Design: Designer
# Best Makeup and Hairstyling: Designer
#  Best Directing: Director
# Best International Feature Film: Director/Producer
# Best Documentary Feature Film: Director/Producer
# Best Documentary Short Film: Director/Producer
# Best Writing (Adapted Screenplay)[22]: Writer
# Date
# : Unknown
# Event
# : Unknown

# %% [markdown]
# Process the nominations and construct the new csv

# %%
# Function to split actors and clean the string
def extract_actors(nomination):
    # First, remove everything after "for" (including "for")
    nomination_clean = re.split(r"\s+for\s+", nomination)[0]

    # Now split the actors by commas or "and"
    actors = re.split(r",|\band\b", nomination_clean)

    # Clean up any extra spaces
    actors = [actor.strip() for actor in actors]

    return actors

# Example usage within the processing loop
processed_nominations = []

for index, row in awards_df.iterrows():
    nomination = row["Nomination"]
    category = row["Category"]

    try:
        # Split nomination at "–"
        parts = nomination.split("– ")

        if len(parts) < 2:
            print(f"Skipping invalid nomination format: {nomination}")
            continue

        part1 = parts[0].strip()  # Actor(s)
        part2 = parts[1].strip()  # Movie

        # Heuristic to determine whether part1 or part2 is the actor or movie
        if any(char.isdigit() for char in part2):  # Movie likely contains a year
            movie_name = part2
            actors = extract_actors(part1)
        else:
            movie_name = part1
            actors = extract_actors(part2)

        # Get the movie release date
        movie_row = movies_df[movies_df["Title"] == movie_name]
        if not movie_row.empty:
            release_date = movie_row["releaseDate"].values[0]
        else:
            release_date = "N/A"

        # Get actor DOBs
        actors_dobs = {}
        for actor in actors:
            actor_row = actors_df[actors_df["Name"] == actor]
            if not actor_row.empty:
                actors_dobs[actor] = actor_row["DOB"].values[0]
            else:
                actors_dobs[actor] = "N/A"

        # Get the role from category_role_mapping
        role = category_role_mapping.get(category, "N/A")

        # Append the processed data to the list
        for actor in actors:
            processed_nominations.append({
                "iteration": row["iteration"],
                "Category": category,
                "Nomination": nomination,
                "Won": row["Won"],
                "Movie": movie_name,
                "Movie Release Date": release_date,
                "Actor": actor,
                "Actor DOB": actors_dobs[actor],
                "Role": role
            })

    except ValueError:
        print(f"Skipping invalid nomination format: {nomination}")
        continue

# Convert to DataFrame
processed_nominations_df = pd.DataFrame(processed_nominations)

# Display the result
print(processed_nominations_df)
processed_nominations_df.to_csv("processed_nominations.csv",index=False)
# Out:
# Skipping invalid nomination format: The Last Bomb
# Skipping invalid nomination format: The True Glory
# Skipping invalid nomination format: Hitler Lives
# Skipping invalid nomination format: Library of Congress
# Skipping invalid nomination format: To the Shores of Iwo Jima
# Skipping invalid nomination format: Donald's Crime - Walt Disney
# Skipping invalid nomination format: Jasper and the Beanstalk  - George Pal
# Skipping invalid nomination format: Life with Feathers - Edward Selzer
# Skipping invalid nomination format: Mighty Mouse in Gypsy Life - Paul Terry
# Skipping invalid nomination format: The Poet and Peasant - Walter Lantz
# Skipping invalid nomination format: Rippling Romance - Ray Katz
# Skipping invalid nomination format: Quiet Please! - Fred Quimby
# Skipping invalid nomination format: Atomic Power
# Skipping invalid nomination format: Life at the Zoo
# Skipping invalid nomination format: Paramount News Issue #37
# Skipping invalid nomination format: Traffic with the Devil
# Skipping invalid nomination format: Seeds of Destiny
# Skipping invalid nomination format: Journey into Medicine
# Skipping invalid nomination format: The World Is Rich
# Skipping invalid nomination format: Design for Death - Sid Rogell, Theron Warth, and Richard Fleischer
# Skipping invalid nomination format: Passport to Nowhere
# Skipping invalid nomination format: School in the Mailbox
# Skipping invalid nomination format: First Steps
# Skipping invalid nomination format: Heart to Heart
# Skipping invalid nomination format: Operation Vittles
# Skipping invalid nomination format: Toward Independence
# Skipping invalid nomination format: Kenji Comes Home
# Skipping invalid nomination format: Daybreak in Udi
# Skipping invalid nomination format: 1848
# Skipping invalid nomination format: The Rising Tide
# Skipping invalid nomination format: A Chance to Live
# Skipping invalid nomination format: So Much for So Little
# Skipping invalid nomination format: Hatch Up Your Troubles
# Skipping invalid nomination format: The Magic Fluke
# Skipping invalid nomination format: Toy Tinkers
# Skipping invalid nomination format: Canary Row (nomination withdrawn by producer)
# Skipping invalid nomination format: For Scent-imental Reasons
# Skipping invalid nomination format: I Was a Communist for the FBI
# Skipping invalid nomination format: Kon-Tiki
# Skipping invalid nomination format: One Who Came Back
# Skipping invalid nomination format: The Seeing Eye
# Skipping invalid nomination format: Benjy
# Skipping invalid nomination format: Ridin' the Rails
# Skipping invalid nomination format: The Story of Time
# Skipping invalid nomination format: World of Kids
# Skipping invalid nomination format: Balzac
# Skipping invalid nomination format: Danger Under the Sea
# Skipping invalid nomination format: Nature's Half Acre
# Skipping invalid nomination format: The Two Mouseketeers
# Skipping invalid nomination format: Lambert the Sheepish Lion
# Skipping invalid nomination format: Rooty Toot Toot
# Skipping invalid nomination format: The Conquest of Everest
# Skipping invalid nomination format: A Queen Is Crowned
# Skipping invalid nomination format: The Living City
# Skipping invalid nomination format: Operation Blue Jay
# Skipping invalid nomination format: They Planted a Stone
# Skipping invalid nomination format: The Word
# Skipping invalid nomination format: Christ Among the Primitives
# Skipping invalid nomination format: Herring Hunt
# Skipping invalid nomination format: Joy of Living
# Skipping invalid nomination format: Wee Water Wonders
# Skipping invalid nomination format: Ben and Me
# Skipping invalid nomination format: Return to Glennascaul
# Skipping invalid nomination format: Vesuvius Express
# Skipping invalid nomination format: Winter Paradise
# Skipping invalid nomination format: Christopher Crumpet
# Skipping invalid nomination format: From A to Z-Z-Z-Z
# Skipping invalid nomination format: Rugged Bear
# Skipping invalid nomination format: The Tell Tale Heart
# Skipping invalid nomination format: Jet Carrier
# Skipping invalid nomination format: Rembrandt: A Self-Portrait
# Skipping invalid nomination format: Thursday's Children
# Skipping invalid nomination format: Hell and High Water
# Skipping invalid nomination format: Them!
# Skipping invalid nomination format: 20,000 Leagues Under the Sea
# Skipping invalid nomination format: The Dam Busters
# Skipping invalid nomination format: The Rains of Ranchipur
# Skipping invalid nomination format: The Bridges at Toko-Ri
# Skipping invalid nomination format: The Naked Eye
# Skipping invalid nomination format: Where Mountains Float
# Skipping invalid nomination format: The Silent World
# Skipping invalid nomination format: A City Decides
# Skipping invalid nomination format: The Dark Wave
# Skipping invalid nomination format: The House Without a Name
# Skipping invalid nomination format: Man in Space
# Skipping invalid nomination format: The True Story of the Civil War
# Skipping invalid nomination format: I Never Forget a Face
# Skipping invalid nomination format: Time Stood Still
# Skipping invalid nomination format: Crashing the Water Barrier
# Skipping invalid nomination format: Cow Dog
# Skipping invalid nomination format: The Dark Wave
# Skipping invalid nomination format: Samoa
# Skipping invalid nomination format: The Bespoke Overcoat
# Skipping invalid nomination format: Gerald McBoing-Boing on Planet Moo
# Skipping invalid nomination format: The Jay Walker
# Skipping invalid nomination format: Magoo's Puddle Jumper
# Skipping invalid nomination format: Mother India (India)
# Skipping invalid nomination format: The Devil Strikes at Night (West Germany)
# Skipping invalid nomination format: Gates of Paris (France)
# Skipping invalid nomination format: Nine Lives (Norway)
# Skipping invalid nomination format: Nights of Cabiria (Italy)
# Skipping invalid nomination format: On the Bowery
# Skipping invalid nomination format: Torero!
# Skipping invalid nomination format: Albert Schweitzer
# Skipping invalid nomination format: A Chairy Tale
# Skipping invalid nomination format: City of Gold
# Skipping invalid nomination format: Foothold on Antarctica
# Skipping invalid nomination format: Portugal
# Skipping invalid nomination format: The Wetback Hound
# Skipping invalid nomination format: One Droopy Knight
# Skipping invalid nomination format: Tabasco Road
# Skipping invalid nomination format: Trees and Jamaica Daddy
# Skipping invalid nomination format: The Truth About Mother Goose
# Skipping invalid nomination format: Birds Anonymous
# Skipping invalid nomination format: Arms and the Man (West Germany)
# Skipping invalid nomination format: Big Deal on Madonna Street (Italy)
# Skipping invalid nomination format: The Road a Year Long (Yugoslavia)
# Skipping invalid nomination format: La venganza (Spain)
# Skipping invalid nomination format: My Uncle (France)
# Skipping invalid nomination format: Antarctic Crossing
# Skipping invalid nomination format: The Hidden World
# Skipping invalid nomination format: Psychiatric Nursing
# Skipping invalid nomination format: Employees Only
# Skipping invalid nomination format: Journey into Spring
# Skipping invalid nomination format: The Living Stone
# Skipping invalid nomination format: Overture
# Skipping invalid nomination format: The Bridge (West Germany)
# Skipping invalid nomination format: The Great War (Italy)
# Skipping invalid nomination format: Paw (Denmark)
# Skipping invalid nomination format: The Village on the River (Netherlands)
# Skipping invalid nomination format: Black Orpheus (France)
# Skipping invalid nomination format: Kapo (Italy)
# Skipping invalid nomination format: Macario (Mexico)
# Skipping invalid nomination format: The Ninth Circle (Yugoslavia)
# Skipping invalid nomination format: La Vérité (France)
# Skipping invalid nomination format: The Virgin Spring (Sweden)
# Skipping invalid nomination format: Rebel in Paradise
# Skipping invalid nomination format: The Horse with the Flying Tail
# Skipping invalid nomination format: Beyond Silence
# Skipping invalid nomination format: A City Called Copenhagen
# Skipping invalid nomination format: George Grosz' Interregnum
# Skipping invalid nomination format: Universe
# Skipping invalid nomination format: Giuseppina
# Skipping invalid nomination format: The Creation of Woman
# Skipping invalid nomination format: Islands of the Sea
# Skipping invalid nomination format: A Sport Is Born
# Skipping invalid nomination format: Day of the Painter
# Skipping invalid nomination format: Goliath II
# Skipping invalid nomination format: High Note
# Skipping invalid nomination format: Mouse and Garden
# Skipping invalid nomination format: A Place in the Sun
# Skipping invalid nomination format: Munro
# Skipping invalid nomination format: Through a Glass Darkly (Sweden)
# Skipping invalid nomination format: Harry and the Butler (Denmark)
# Skipping invalid nomination format: Immortal Love (Japan)
# Skipping invalid nomination format: The Important Man (Mexico)
# Skipping invalid nomination format: Plácido (Spain)
# Skipping invalid nomination format: Sky Above and Mud Beneath
# Skipping invalid nomination format: The Grand Olympics
# Skipping invalid nomination format: Project Hope
# Skipping invalid nomination format: Breaking the Language Barrier
# Skipping invalid nomination format: Cradle of Genius
# Skipping invalid nomination format: Kahl
# Skipping invalid nomination format: The Man in Gray
# Skipping invalid nomination format: Seawards the Great Ships
# Skipping invalid nomination format: The Face of Jesus
# Skipping invalid nomination format: Play Ball!
# Skipping invalid nomination format: Rooftops of New York
# Skipping invalid nomination format: Very Nice, Very Nice
# Skipping invalid nomination format: Surogat
# Skipping invalid nomination format: Aquamania
# Skipping invalid nomination format: Beep Prepared
# Skipping invalid nomination format: Nelly's Folly
# Skipping invalid nomination format: The Pied Piper of Guadalupe
# Skipping invalid nomination format: Sundays and Cybele (France)
# Skipping invalid nomination format: Electra (Greece)
# Skipping invalid nomination format: The Four Days of Naples (Italy)
# Skipping invalid nomination format: Keeper of Promises (The Given Word) (Brazil)
# Skipping invalid nomination format: Tlayucan (Mexico)
# Skipping invalid nomination format: Black Fox
# Skipping invalid nomination format: Alvorada
# Skipping invalid nomination format: Dylan Thomas
# Skipping invalid nomination format: The John Glenn Story
# Skipping invalid nomination format: The Road to the Wall
# Skipping invalid nomination format: Heureux Anniversaire
# Skipping invalid nomination format: Big City Blues
# Skipping invalid nomination format: The Cadillac
# Skipping invalid nomination format: The Cliff Dwellers
# Skipping invalid nomination format: Pan
# Skipping invalid nomination format: The Hole
# Skipping invalid nomination format: Icarus Montgolfier Wright
# Skipping invalid nomination format: Now Hear This
# Skipping invalid nomination format: Self Defense ... for Cowards
# Skipping invalid nomination format: A Symposium on Popular Songs
# Skipping invalid nomination format: Knife in the Water (Poland)
# Skipping invalid nomination format: The Red Lanterns (Greece)
# Skipping invalid nomination format: Los Tarantos (Spain)
# Skipping invalid nomination format: Twin Sisters of Kyoto (Japan)
# Skipping invalid nomination format: 8½ (Italy)
# Skipping invalid nomination format: Le Maillon et la Chaine
# Skipping invalid nomination format: The Yanks Are Coming
# Skipping invalid nomination format: Terminus (nomination revoked)
# Skipping invalid nomination format: Robert Frost: A Lover's Quarrel with the World
# Skipping invalid nomination format: The Five Cities of June
# Skipping invalid nomination format: The Spirit of America
# Skipping invalid nomination format: Thirty Million Letters
# Skipping invalid nomination format: To Live Again
# Skipping invalid nomination format: Chagall
# Skipping invalid nomination format: The Concert
# Skipping invalid nomination format: The Home-Made Car
# Skipping invalid nomination format: The Six-Sided Triangle
# Skipping invalid nomination format: That's Me
# Skipping invalid nomination format: An Occurrence at Owl Creek Bridge
# Skipping invalid nomination format: Automania 2000
# Skipping invalid nomination format: The Game
# Skipping invalid nomination format: My Financial Career
# Skipping invalid nomination format: Pianissimo
# Skipping invalid nomination format: The Critic
# Skipping invalid nomination format: Sophia Loren - Marriage Italian Style as Filumena Marturano
# Skipping invalid nomination format: Raven's End (Sweden)
# Skipping invalid nomination format: Sallah Shabati (Israel)
# Skipping invalid nomination format: The Umbrellas of Cherbourg (France)
# Skipping invalid nomination format: Woman in the Dunes (Japan)
# Skipping invalid nomination format: Yesterday, Today and Tomorrow (Italy)
# Skipping invalid nomination format: 14-18
# Skipping invalid nomination format: The Finest Hours
# Skipping invalid nomination format: Four Days in November
# Skipping invalid nomination format: The Human Dutch
# Skipping invalid nomination format: Jacques-Yves Cousteau's World Without Sun
# Skipping invalid nomination format: 140 Days Under the World
# Skipping invalid nomination format: Breaking the Habit
# Skipping invalid nomination format: Children Without
# Skipping invalid nomination format: Eskimo Artist: Kenojuak
# Skipping invalid nomination format: Nine from Little Rock
# Skipping invalid nomination format: Help! My Snowman's Burning Down
# Skipping invalid nomination format: The Legend of Jimmy Blue Eyes
# Skipping invalid nomination format: Casals Conducts: 1964
# Skipping invalid nomination format: Christmas Cracker
# Skipping invalid nomination format: How to Avoid Friendship
# Skipping invalid nomination format: Nudnik #2
# Skipping invalid nomination format: The Pink Phink
# Skipping invalid nomination format: Blood on the Land (Greece)
# Skipping invalid nomination format: Dear John (Sweden)
# Skipping invalid nomination format: Kwaidan (Japan)
# Skipping invalid nomination format: Marriage Italian Style (Italy)
# Skipping invalid nomination format: The Shop on Main Street (Czechoslovakia)
# Skipping invalid nomination format: The Battle of the Bulge... The Brave Rifles
# Skipping invalid nomination format: The Forth Road Bridge
# Skipping invalid nomination format: Let My People Go: The Story of Israel
# Skipping invalid nomination format: To Die in Madrid
# Skipping invalid nomination format: The Eleanor Roosevelt Story
# Skipping invalid nomination format: Mural on Our Street
# Skipping invalid nomination format: Nyitany
# Skipping invalid nomination format: Point of View
# Skipping invalid nomination format: Yeats Country
# Skipping invalid nomination format: To Be Alive!
# Skipping invalid nomination format: Skaterdater
# Skipping invalid nomination format: Snow
# Skipping invalid nomination format: Clay or the Origin of Species
# Skipping invalid nomination format: The Thieving Magpie
# Skipping invalid nomination format: The Dot and the Line
# Skipping invalid nomination format: The Battle of Algiers (Italy)
# Skipping invalid nomination format: Loves of a Blonde (Czechoslovakia)
# Skipping invalid nomination format: Pharaoh (Poland)
# Skipping invalid nomination format: Three (Yugoslavia)
# Skipping invalid nomination format: A Man and a Woman (France)
# Skipping invalid nomination format: The Face of a Genius
# Skipping invalid nomination format: Helicopter Canada
# Skipping invalid nomination format: The Really Big Family
# Skipping invalid nomination format: Le Volcan interdit
# Skipping invalid nomination format: The War Game
# Skipping invalid nomination format: Adolescence
# Skipping invalid nomination format: Cowboy
# Skipping invalid nomination format: The Odds Against
# Skipping invalid nomination format: Részletek J.S. Bach Máté passiójából
# Skipping invalid nomination format: Bonnie and Clyde — Warren Beatty, producer
# Skipping invalid nomination format: Doctor Dolittle — Arthur P. Jacobs, producer
# Skipping invalid nomination format: The Graduate — Lawrence Turman, producer
# Skipping invalid nomination format: Guess Who's Coming to Dinner — Stanley Kramer, producer
# Skipping invalid nomination format: In the Heat of the Night — Walter Mirisch, producer
# Skipping invalid nomination format: El amor brujo (Spain)
# Skipping invalid nomination format: I Even Met Happy Gypsies (Yugoslavia)
# Skipping invalid nomination format: Live for Life (France)
# Skipping invalid nomination format: Portrait of Chieko (Japan)
# Skipping invalid nomination format: Closely Watched Trains (Czechoslovakia)
# Skipping invalid nomination format: Festival
# Skipping invalid nomination format: Harvest
# Skipping invalid nomination format: A King's Story
# Skipping invalid nomination format: A Time for Burning
# Skipping invalid nomination format: The Anderson Platoon
# Skipping invalid nomination format: Monument to the Dream
# Skipping invalid nomination format: A Place to Stand
# Skipping invalid nomination format: See You at the Pillar
# Skipping invalid nomination format: While I Run This Race
# Skipping invalid nomination format: Hypothese Beta
# Skipping invalid nomination format: What on Earth!
# Skipping invalid nomination format: The Box
# Skipping invalid nomination format: "The Bare Necessities" from The Jungle Book — Music and Lyrics by Terry Gilkyson
# Skipping invalid nomination format: "The Eyes of Love" from Banning — Music by Quincy Jones; Lyrics by Bob Russell
# Skipping invalid nomination format: "The Look of Love" from Casino Royale — Music by Burt Bacharach; Lyrics by Hal David
# Skipping invalid nomination format: "Thoroughly Modern Millie" from Thoroughly Modern Millie — Music by Jimmy Van Heusen; Lyrics by Sammy Cahn
# Skipping invalid nomination format: "Talk to the Animals" from Doctor Dolittle — Music and Lyrics by Leslie Bricusse
# Skipping invalid nomination format: Before the Mountain Was Moved
# Skipping invalid nomination format: In the Year of the Pig
# Skipping invalid nomination format: Olimpiada en México
# Skipping invalid nomination format: The Wolf Men
# Skipping invalid nomination format: An Impression of John Steinbeck: Writer
# Skipping invalid nomination format: Jenny Is a Good Thing
# Skipping invalid nomination format: Leo Beuerman
# Skipping invalid nomination format: The Magic Machines
# Skipping invalid nomination format: Ådalen 31 (Sweden)
# Skipping invalid nomination format: Battle of Neretva (Yugoslavia)
# Skipping invalid nomination format: The Brothers Karamazov (Soviet Union)
# Skipping invalid nomination format: My Night at Maud's (France)
# Skipping invalid nomination format: Z (Algeria)
# Skipping invalid nomination format: Hello, Dolly! — William H. Reynolds
# Skipping invalid nomination format: Midnight Cowboy — Hugh A. Robertson
# Skipping invalid nomination format: The Secret of Santa Vittoria — William Lyon and Earle Herdan
# Skipping invalid nomination format: They Shoot Horses, Don't They? — Fredric Steinkamp
# Skipping invalid nomination format: Z — Françoise Bonnot
# Skipping invalid nomination format: The Gifts - Robert McBride
# Skipping invalid nomination format: A Long Way from Nowhere - Bob Aller
# Skipping invalid nomination format: Oisín - Patrick Carey and Vivien Carey
# Skipping invalid nomination format: Time Is Running Out - Horst Dallmayr and Robert Menegoz
# Skipping invalid nomination format: First Love (Switzerland)
# Skipping invalid nomination format: Hoa-Binh (France)
# Skipping invalid nomination format: Paix sur les champs (Belgium)
# Skipping invalid nomination format: Tristana (Spain)
# Skipping invalid nomination format: Investigation of a Citizen Above Suspicion (Italy)
# Skipping invalid nomination format: Background
# Skipping invalid nomination format: Christo's Valley Curtain
# Skipping invalid nomination format: Four Stones for Kanemitsu
# Skipping invalid nomination format: Paisti ag obair
# Skipping invalid nomination format: "All That Love Went to Waste" — A Touch of Class • Music by George Barrie • Lyrics by Sammy Cahn
# Skipping invalid nomination format: "Live and Let Die" — Live and Let Die • Music and Lyrics by Paul McCartney and Linda McCartney
# Skipping invalid nomination format: "Love" — Robin Hood • Music by George Bruns • Lyrics by Floyd Huddleston
# Skipping invalid nomination format: "(You're So) Nice to Be Around" — Cinderella Liberty • Music by John Williams • Lyrics by Paul Williams
# Skipping invalid nomination format: "The Way We Were" — The Way We Were • Music by Marvin Hamlisch • Lyrics by Alan and Marilyn Bergman
# Skipping invalid nomination format: American Graffiti — Verna Fields and Marcia Lucas
# Skipping invalid nomination format: The Day of the Jackal — Ralph Kemplen
# Skipping invalid nomination format: Jonathan Livingston Seagull — Frank P. Keller and James Galloway
# Skipping invalid nomination format: The Sting — William H. Reynolds
# Skipping invalid nomination format: City Out of Wilderness
# Skipping invalid nomination format: Exploratorium
# Skipping invalid nomination format: John Muir's High Sierra
# Skipping invalid nomination format: Naked Yoga
# Skipping invalid nomination format: "Benji's Theme (I Feel Love)" — Benji • Music by Euel Box • Lyrics by Betty Box
# Skipping invalid nomination format: "Blazing Saddles" — Blazing Saddles • Music by John Morris • Lyrics by Mel Brooks
# Skipping invalid nomination format: "Little Prince" — The Little Prince • Music by Frederick Loewe • Lyrics by Alan Jay Lerner
# Skipping invalid nomination format: "Wherever Love Takes Me" — Gold • Music by Elmer Bernstein • Lyrics by Don Black
# Skipping invalid nomination format: "We May Never Love Like This Again" — The Towering Inferno • Music and Lyrics by Al Kasha and Joel Hirschhorn
# Skipping invalid nomination format: Blazing Saddles — John C. Howard and Danford Greene
# Skipping invalid nomination format: Chinatown — Sam O'Steen
# Skipping invalid nomination format: Earthquake — Dorothy Spencer
# Skipping invalid nomination format: The Longest Yard — Michael Luciano
# Skipping invalid nomination format: The Towering Inferno — Harold F. Kress and Carl Kress
# Skipping invalid nomination format: Letters from Marusia (Mexico)
# Skipping invalid nomination format: Profumo di donna (Italy)
# Skipping invalid nomination format: The Promised Land (Poland)
# Skipping invalid nomination format: Sandakan No. 8 (Japan)
# Skipping invalid nomination format: Dersu Uzala (Soviet Union)
# Skipping invalid nomination format: Arthur and Lillie
# Skipping invalid nomination format: Millions of Years Ahead of Man
# Skipping invalid nomination format: Probes in Space
# Skipping invalid nomination format: Whistling Smith
# Skipping invalid nomination format: Cousin Cousine (France)
# Skipping invalid nomination format: Jacob the Liar (East Germany)
# Skipping invalid nomination format: Nights and Days (Poland)
# Skipping invalid nomination format: Seven Beauties (Italy)
# Skipping invalid nomination format: Black and White in Color (Côte d'Ivoire)
# Skipping invalid nomination format: American Shoeshine - Sparky Greene
# Skipping invalid nomination format: Blackwood - Tony Ianzelo and Andy Thomson
# Skipping invalid nomination format: The End of the Road - John Armstrong
# Skipping invalid nomination format: Universe - Lester Novros
# Skipping invalid nomination format: Coming Home - Jerome Hellman, producer
# Skipping invalid nomination format: An Unmarried Woman - Paul Mazursky and Anthony Ray, producers
# Skipping invalid nomination format: Alsino and the Condor (Nicaragua)
# Skipping invalid nomination format: Clean Slate (France)
# Skipping invalid nomination format: Flight of the Eagle (Sweden)
# Skipping invalid nomination format: Private Life (Union of Soviet Socialist Republics)
# Skipping invalid nomination format: Begin the Beguine (Spain)
# Skipping invalid nomination format: 2010 –Michael J. Kohut, Aaron Rochin, Carlos Delarios and Gene Cantamessa
# Skipping invalid nomination format: A.I. Artificial Intelligence — John Williams
# Skipping invalid nomination format: A Beautiful Mind — James Horner
# Skipping invalid nomination format: Harry Potter and the Sorcerer's Stone — John Williams
# Skipping invalid nomination format: Monsters, Inc. — Randy Newman
# Skipping invalid nomination format: The Lord of the Rings: The Fellowship of the Ring — Howard Shore
# Skipping invalid nomination format: The Barbarian Invasions - Denys Arcand
# Skipping invalid nomination format: Manon on the Asphalt — Elizabeth Marre and Olivier Pont
# Skipping invalid nomination format: New Boy — Steph Green and Tamara Anghie
# Skipping invalid nomination format: On the Line (Auf der Strecke) — Reto Caffi
# Skipping invalid nomination format: The Pig (Grisen) — Tivi Magnusson and Dorte Høgh
# Skipping invalid nomination format: Toyland (Spielzeugland) — Jochen Alexander Freydank
# Skipping invalid nomination format: The Martian –Production Design: Arthur Max; Set Decoration: Celia Bobak
# Skipping invalid nomination format: Knight of Fortune –Lasse Lyskjær Noer and Christian Norlyk
#        iteration                Category  \
# 0             10  Outstanding Production
# 1             10  Outstanding Production
# 2             10  Outstanding Production
# 3             10  Outstanding Production
# 4             10  Outstanding Production
# ...          ...                     ...
# 15040         96     Best Visual Effects
# 15041         96     Best Visual Effects
# 15042         96     Best Visual Effects
# 15043         96     Best Visual Effects
# 15044         96     Best Visual Effects
#
#                                               Nomination  Won  \
# 0      The Awful Truth – Leo McCarey and Everett Risk...    0
# 1      The Awful Truth – Leo McCarey and Everett Risk...    0
# 2      Captains Courageous – Louis D. Lighton for Met...    0
# 3      Dead End – Samuel Goldwyn and Merritt Hulbert ...    0
# 4      Dead End – Samuel Goldwyn and Merritt Hulbert ...    0
# ...                                                  ...  ...
# 15040  Godzilla Minus One – Takashi Yamazaki, Kiyoko ...    1
# 15041  Godzilla Minus One – Takashi Yamazaki, Kiyoko ...    1
# 15042  Godzilla Minus One – Takashi Yamazaki, Kiyoko ...    1
# 15043  Godzilla Minus One – Takashi Yamazaki, Kiyoko ...    1
# 15044  Godzilla Minus One – Takashi Yamazaki, Kiyoko ...    1
#
#                      Movie Movie Release Date             Actor  \
# 0          The Awful Truth         1937-10-21       Leo McCarey
# 1          The Awful Truth         1937-10-21    Everett Riskin
# 2      Captains Courageous         1937-05-11  Louis D. Lighton
# 3                 Dead End         1937-08-27    Samuel Goldwyn
# 4                 Dead End         1937-08-27   Merritt Hulbert
# ...                    ...                ...               ...
# 15040   Godzilla Minus One                N/A  Takashi Yamazaki
# 15041   Godzilla Minus One                N/A    Kiyoko Shibuya
# 15042   Godzilla Minus One                N/A  Masaki Takahashi
# 15043   Godzilla Minus One                N/A
# 15044   Godzilla Minus One                N/A    Tatsuji Nojima
#
#                                         Actor DOB                   Role
# 0                                      1898-10-03               Producer
# 1                                             N/A               Producer
# 2                                      1895-11-25               Producer
# 3                                      1882-08-27               Producer
# 4                                             N/A               Producer
# ...                                           ...                    ...
# 15040                                  1964-06-12  Sound/Visual Engineer
# 15041              1970 (age 54–55) Tokyo , Japan  Sound/Visual Engineer
# 15042  1968 (age 56–57) [ 1 ] Tokyo , Japan [ 1 ]  Sound/Visual Engineer
# 15043                                         N/A  Sound/Visual Engineer
# 15044                                  1998-10-13  Sound/Visual Engineer
#
# [15045 rows x 9 columns]

# %% [markdown]
# ** This last cell was used to see the different lengths of attributes to update the schema as to minimise the size **

# %%
# Find the largest actor name
largest_actor_name = actors_df['Birth Country'].apply(len).idxmax()
largest_actor_name_value = actors_df.loc[largest_actor_name, 'Birth Country']

# Find the largest movie title
largest_movie_name = movies_df['Language'].apply(len).idxmax()
largest_movie_name_value = movies_df.loc[largest_movie_name, 'Language']

len(largest_actor_name_value), len(largest_movie_name_value)
# Out:
# (78, 40)
